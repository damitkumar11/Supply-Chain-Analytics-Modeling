# %% [markdown]
# <a href="https://colab.research.google.com/github/damitkumar11/Supply-Chain-Analytics-Modeling/blob/main/Supply_Chain_Analytics_%26_Modeling_(LightGBM_%26_RNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Introduction**
#
# In this supply chain analytics analysis, we encountered the challenge of working with a dataset consisting of 100 rows and 24 columns. During the Exploratory Data Analysis phase, we conducted quality control checks, assessed supply chain risks, performed Inventory Optimization Analysis using the Economic Order Quantity (EOQ) method, conducted customer segmentation analysis, and explored lead times optimization. However, in the modeling phase, we found that using LightGBM and RNN models was not suitable for this small dataset, resulting in unsatisfactory outcomes. Therefore, we recommend utilizing a larger dataset or considering alternatives such as linear regression, decision trees, or random forests to achieve better results in cost optimization and demand forecasting.In this supply chain analytics analysis, we encountered the challenge of working with a dataset consisting of 100 rows and 24 columns. During the Exploratory Data Analysis phase, we conducted quality control checks, assessed supply chain risks, performed Inventory Optimization Analysis using the Economic Order Quantity (EOQ) method, conducted customer segmentation analysis, and explored lead times optimization. However, in the modeling phase, we found that using LightGBM and RNN models was not suitable for this small dataset, resulting in unsatisfactory outcomes. Therefore, we recommend utilizing a larger dataset or considering alternatives such as linear regression, decision trees, or random forests to achieve better results in cost optimization and demand forecasting.

# %% [markdown]
# **Load data**

# %%
# Disable warning

import warnings

warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
import pandas as pd

supply_data = pd.read_csv("/content/supply_chain_data.csv")

# %%
supply_data.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# 2                88  ...    Mumbai        12                 971
# 3                59  ...   Kolkata        24                 937
# 4                56  ...     Delhi         5                 414
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                      29           46.279879             Pending
# 1                      30           33.616769             Pending
# 2                      27           30.688019             Pending
# 3                      18           35.624741                Fail
# 4                       3           92.065161                Fail
#
#    Defect rates  Transportation modes   Routes       Costs
# 0      0.226410                  Road  Route B  187.752075
# 1      4.854068                  Road  Route B  503.065579
# 2      4.580593                   Air  Route C  141.920282
# 3      4.746649                  Rail  Route A  254.776159
# 4      3.145580                   Air  Route A  923.440632
#
# [5 rows x 24 columns]

# %%
supply_data.shape
# Out:
# (100, 24)

# %%
supply_data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %% [markdown]
# **Feature explanation**
#
# * **Product Type:** The type of product associated with specific data in the supply chain.
# * **SKU (Stock Keeping Unit):** Unique code used to identify a particular product.
# * **Price:** The price of the product or item in the supply chain.
# * **Availability:** Information about product availability.
# * **Number of Products Sold:** The number of products that have been sold in a certain time period.
# * **Revenue Generated:** Total revenue generated from product sales in a certain time period.
# * **Customer demographics:** Information about customer characteristics, such as age, gender, geographic location, etc.
# * **Stock Levels:** The number of products still available in stock at any given time.
# * **Lead Times:** The time required to order or receive products from suppliers.
# * **Order Quantities:** The number of products ordered in one order or shipment.
# * **Shipping Times:** The time required to ship products from the warehouse or distribution center to customers.
# * **Shipping Carriers:** Companies or services used to ship products to customers.
# * **Shipping Costs:** Costs associated with shipping products, including delivery fees and additional fees.
# * **Supplier Name:** Name of supplier or vendor who provides products or materials to the company.
# * **Location:** The physical location associated with the data in the supply chain, such as the location of a warehouse or distribution center.
# * **Lead Time:** The time required to obtain products or materials from a particular supplier.
# * **Production Volumes:** The number of products produced in a certain time period.
# * **Manufacturing Lead Time:** The time required to produce a product, from ordering materials until the product is ready.
# * **Manufacturing Costs:** Costs related to the production process, including raw material costs, labor, etc.
# * **Inspection Results:** Results of product or material quality inspection.
# * **Defect Rates:** The level of defects or defects in the products produced.
# * **Transportation Modes:** The transportation mode used to send products, such as land, sea or air.
# * **Routes:** Routes or paths used to send products from one point to another in the supply chain.
# * **Costs:** Costs related to various aspects of the supply chain, including transportation costs, production costs, and other costs.

# %%
supply_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
#  14  Location                 100 non-null    object
#  15  Lead time                100 non-null    int64
#  16  Production volumes       100 non-null    int64
#  17  Manufacturing lead time  100 non-null    int64
#  18  Manufacturing costs      100 non-null    float64
#  19  Inspection results       100 non-null    object
#  20  Defect rates             100 non-null    float64
#  21  Transportation modes     100 non-null    object
#  22  Routes                   100 non-null    object
#  23  Costs                    100 non-null    float64
# dtypes: float64(6), int64(9), object(9)
# memory usage: 18.9+ KB

# %% [markdown]
# **Data preprocessing**
#
#
# Checking for missing values

# %%
# Check for missing values
missing_values = supply_data.isnull().sum()

# Display columns with missing values and the count of missing values
missing_values = missing_values[missing_values > 0]

if not missing_values.empty:
    print("Columns with missing values:")
    for column, count in missing_values.items():
        print(f"{column}: {count} missing values")
else:
    print("There are no columns with missing value")
# Out:
# There are no columns with missing value

# %% [markdown]
# **Check for duplicate data**

# %%
if supply_data.duplicated().any():
    print(f"There are as many as {supply_data.duplicated().sum()} duplicate data.")
else:
    print("There are no duplicate data.")
# Out:
# There are no duplicate data.

# %% [markdown]
# **Exploratory Data Analysis**
#
#
# Quality control check

# %%
import plotly.express as px

defect_rates_by_product = supply_data.groupby("Product type")['Defect rates'].mean().reset_index()

# Create a bar chart using Plotly
fig = px.bar(defect_rates_by_product, x='Product type', y='Defect rates', title='Defect Rates by Product Type')

# Customize the color scale for bars
color_scale = px.colors.qualitative.Set3  # You can choose a different color scale
fig.update_traces(marker_color=color_scale)

# Customize the appearance of the chart
fig.update_layout(
    xaxis_title="Product Type",
    yaxis_title="Mean Defect Rates",
    xaxis=dict(categoryorder='total descending'),
    yaxis=dict(title='Mean Defect Rates'),
    plot_bgcolor='white',
    title_x=0.5,
    showlegend=True  # Hide the legend
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4abc0bfb-35f0-42aa-b678-2204b5de3d85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4abc0bfb-35f0-42aa-b678-2204b5de3d85")) {                    Plotly.newPlot(                        "4abc0bfb-35f0-42aa-b678-2204b5de3d85",                        [{"alignmentgroup":"True","hovertemplate":"Product type=%{x}\u003cbr\u003eDefect rates=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)","rgb(179,222,105)","rgb(252,205,229)","rgb(217,217,217)","rgb(188,128,189)","rgb(204,235,197)","rgb(255,237,111)"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["cosmetics","haircare","skincare"],"xaxis":"x","y":[1.9192869782813182,2.4831501929246245,2.334680781980237],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}]," ...

# %% [markdown]
# **Supply chain risk assessment**

# %%
risk_data = supply_data[['SKU', 'Lead times', 'Stock levels']]
risk_data.head()
# Out:
#     SKU  Lead times  Stock levels
# 0  SKU0           7            58
# 1  SKU1          30            53
# 2  SKU2          10             1
# 3  SKU3          13            23
# 4  SKU4           3             5

# %%
risk_data['Risk score'] = risk_data['Lead times'] * (1-risk_data.loc[:,'Stock levels'])

# %%
# Sort the risk_data by 'Risk score' in descending order and select top 10 highest-risk data
risk_data = risk_data.sort_values(by='Risk score', ascending=False)[:10]

# Create a bar plot using Plotly Express
fig = px.bar(risk_data, x='SKU', y='Risk score', title='Top 10 Highest-Risk Data',
             labels={'Risk score': 'Risk Score', 'SKU': 'SKU'},
             text='Risk score')

# Customize the appearance of the plot
fig.update_traces(texttemplate='%{text:.2f}', textposition='outside')
fig.update_layout(xaxis_title='SKU', yaxis_title='Risk Score', title_x=0.5)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d3768342-22b7-4a0e-af95-4ea031350829" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3768342-22b7-4a0e-af95-4ea031350829")) {                    Plotly.newPlot(                        "d3768342-22b7-4a0e-af95-4ea031350829",                        [{"alignmentgroup":"True","hovertemplate":"SKU=%{x}\u003cbr\u003eRisk Score=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[8.0,0.0,0.0,-5.0,-12.0,-16.0,-28.0,-37.0,-40.0,-45.0],"textposition":"outside","x":["SKU68","SKU2","SKU34","SKU16","SKU4","SKU78","SKU87","SKU76","SKU8","SKU47"],"xaxis":"x","y":[8,0,0,-5,-12,-16,-28,-37,-40,-45],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0. ...

# %% [markdown]
# **Inventory Optimization Analysis with EOQ**

# %%
# we assume for holding cost 0.2
holdingcost = 0.2

# %%
import numpy as np

def calculate_eoq(data):
    S = data['Costs']
    D = data['Number of products sold']
    H = data['Number of products sold'] * holdingcost
    EOQ = np.sqrt((2*S*D)/H)
    return round(EOQ)

# %%
supply_data['EOQ'] = calculate_eoq(supply_data)

# %%
comparison_columns = supply_data[['SKU', 'EOQ','Order quantities']]
comparison_columns.head()
# Out:
#     SKU   EOQ  Order quantities
# 0  SKU0  43.0                96
# 1  SKU1  71.0                37
# 2  SKU2  38.0                88
# 3  SKU3  50.0                59
# 4  SKU4  96.0                56

# %%
# Extracting the top 10 rows for comparison
top_10_comparison = comparison_columns.head(10)

# Creating a bar plot to compare EOQ and Order Quantities for the top 10 SKUs
fig = px.bar(top_10_comparison, x='SKU', y=['EOQ', 'Order quantities'],
             title='Comparison of EOQ and Order Quantities for Top 10 SKUs')

fig.update_layout(
    title_x=0.5
)

# Displaying the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="df0ad487-c348-4462-bc6a-32d2f4d6ba05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df0ad487-c348-4462-bc6a-32d2f4d6ba05")) {                    Plotly.newPlot(                        "df0ad487-c348-4462-bc6a-32d2f4d6ba05",                        [{"alignmentgroup":"True","hovertemplate":"variable=EOQ\u003cbr\u003eSKU=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EOQ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"EOQ","offsetgroup":"EOQ","orientation":"v","showlegend":true,"textposition":"auto","x":["SKU0","SKU1","SKU2","SKU3","SKU4","SKU5","SKU6","SKU7","SKU8","SKU9"],"xaxis":"x","y":[43.0,71.0,38.0,50.0,96.0,49.0,37.0,90.0,71.0,100.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Order quantities\u003cbr\u003eSKU=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Order quantities","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Order quantities","offsetgroup":"Order quantities","orientation":"v","showlegend":true,"textposition":"auto","x":["SKU0","SKU1","SKU2","SKU3","SKU4","SKU5","SKU6","SKU7","SKU8","SKU9"],"xaxis":"x","y":[96.0,37.0,88.0,59.0,56.0,66.0,58.0,11.0,15.0,83.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f ...

# %% [markdown]
# **Customer segmentation analysis**

# %%
revenue_avg_by_demo_prod = supply_data.groupby(['Customer demographics', 'Product type'])['Revenue generated'].mean().reset_index()
revenue_sum_by_demo_prod = supply_data.groupby(['Customer demographics', 'Product type'])['Revenue generated'].sum().reset_index()

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Create a palette of different colors for each product type
colors = px.colors.qualitative.Set3

# Create a subplot with 1 row and 2 columns
fig = make_subplots(rows=1, cols=2, subplot_titles=('Average Revenue', 'Total Revenue'))

# Plot for average revenue
for i, product_type in enumerate(revenue_avg_by_demo_prod['Product type'].unique()):
    subset = revenue_avg_by_demo_prod[revenue_avg_by_demo_prod['Product type'] == product_type]
    fig.add_trace(
        go.Bar(
            x=subset['Customer demographics'],
            y=subset['Revenue generated'],
            name=product_type,
            marker_color=colors[i]
        ),
        row=1, col=1
    )

# Plot for total revenue without legend
for i, product_type in enumerate(revenue_sum_by_demo_prod['Product type'].unique()):
    subset = revenue_sum_by_demo_prod[revenue_sum_by_demo_prod['Product type'] == product_type]
    fig.add_trace(
        go.Bar(
            x=subset['Customer demographics'],
            y=subset['Revenue generated'],
            showlegend=False,  # Hide legend for this subplot
            marker_color=colors[i]
        ),
        row=1, col=2
    )

# Beautify the subplot and show the legend for the first subplot
fig.update_layout(
    title='Revenue Analysis by Customer Demographics and Product Type',
    xaxis=dict(title='Customer Demographics'),
    yaxis=dict(title='Revenue'),
    xaxis2=dict(title='Customer Demographics'),
    yaxis2=dict(title='Revenue'),
    title_x=0.5,
    showlegend=True  # Show legend for the first subplot
)

# Show the subplot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7394d291-2584-48c1-8ab0-713674466b34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7394d291-2584-48c1-8ab0-713674466b34")) {                    Plotly.newPlot(                        "7394d291-2584-48c1-8ab0-713674466b34",                        [{"marker":{"color":"rgb(141,211,199)"},"name":"cosmetics","x":["Female","Male","Non-binary","Unknown"],"y":[6954.854219685358,5347.7413743343,5247.096332116826,6335.182377815462],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(255,255,179)"},"name":"haircare","x":["Female","Male","Non-binary","Unknown"],"y":[6362.416641586338,5059.992730921369,5567.306726391122,4810.63219522254],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(190,186,218)"},"name":"skincare","x":["Female","Male","Non-binary","Unknown"],"y":[6095.470280123415,7806.214493320447,4650.8338885715775,6287.152695992038],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(141,211,199)"},"showlegend":false,"x":["Female","Male","Non-binary","Unknown"],"y":[69548.54219685358,21390.9654973372,26235.48166058413,44346.27664470823],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"rgb(255,255,179)"},"showlegend":false,"x":["Female","Male","Non-binary","Unknown"],"y":[12724.833283172677,50599.927309213694,38971.14708473785,72159.4829283381],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"rgb(190,186,218)"},"showlegend":false,"x":["Female","Male","Non-binary","Unknown"],"y":[79241.1136416044,54643.50145324313,51159.17277428735,56584.374263928345],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"o ...

# %% [markdown]
# **Lead times optimization analysis**

# %%
avg_lead_times_transport = supply_data.groupby(['Transportation modes'])['Lead times'].mean().reset_index()

fig = px.bar(avg_lead_times_transport, x='Transportation modes', y='Lead times',
             labels={'Transportation modes': 'Transportation Mode', 'Lead times': 'Average Lead Time'},
             title='Average Lead Times by Transportation Mode')

# Customize the color scale for bars
color_scale = px.colors.qualitative.Set3  # You can choose a different color scale
fig.update_traces(marker_color=color_scale)

# Customize the layout for beautification
fig.update_layout(
    title=dict(text='Average Lead Times by Transportation Mode', x=0.5),
    xaxis_title='Transportation Mode',
    yaxis_title='Average Lead Time',
    xaxis_tickangle=-45,  # Rotate x-axis labels for better readability
    font=dict(family="Arial", size=14),
    showlegend=False  # Remove legend
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c020840f-261d-4bc5-b29c-46311504e148" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c020840f-261d-4bc5-b29c-46311504e148")) {                    Plotly.newPlot(                        "c020840f-261d-4bc5-b29c-46311504e148",                        [{"alignmentgroup":"True","hovertemplate":"Transportation Mode=%{x}\u003cbr\u003eAverage Lead Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)","rgb(179,222,105)","rgb(252,205,229)","rgb(217,217,217)","rgb(188,128,189)","rgb(204,235,197)","rgb(255,237,111)"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Air","Rail","Road","Sea"],"xaxis":"x","y":[18.26923076923077,14.892857142857142,17.137931034482758,12.176470588235293],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewi ...

# %%
best_transportation_mode = avg_lead_times_transport.loc[avg_lead_times_transport['Lead times'].idxmin()]
best_transportation_mode
# Out:
# Transportation modes          Sea
# Lead times              12.176471
# Name: 3, dtype: object

# %%
best_transportation_data = supply_data[supply_data['Transportation modes']==best_transportation_mode['Transportation modes']]
best_transportation_data.head()
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 6      skincare   SKU6   4.078333            48                       65
# 8     cosmetics   SKU8  68.717597            78                      150
# 15     skincare  SKU15  36.989245            94                      469
# 18     haircare  SKU18  36.443628            23                      620
# 27    cosmetics  SKU27  92.557361            42                      352
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 6         7823.476560                  Male            11          15
# 8         7517.363211                Female             5          10
# 15        5442.086785            Non-binary             9           8
# 18        9364.673505               Unknown            10          10
# 27        2686.457224               Unknown            47           9
#
#     Order quantities  ...  Lead time Production volumes  \
# 6                 58  ...         14                314
# 8                 15  ...         13                769
# 15                69  ...         14                580
# 18                46  ...         18                374
# 27                62  ...         25                291
#
#     Manufacturing lead time Manufacturing costs Inspection results  \
# 6                        24            1.085069            Pending
# 8                         8           11.423027            Pending
# 15                        7           97.121282               Pass
# 18                       17           27.107981            Pending
# 27                        4           10.528245               Fail
#
#     Defect rates  Transportation modes   Routes       Costs   EOQ
# 6       1.000911                   Sea  Route A  134.369097  37.0
# 8       2.709863                   Sea  Route B  505.557134  71.0
# 15      2.264406                   Sea  Route B  127.861800  36.0
# 18      2.231939                   Sea  Route A  593.480259  77.0
# 27      2.864668                   Sea  Route B  762.459182  87.0
#
# [5 rows x 25 columns]

# %%
import plotly.express as px

avg_lead_times_route = supply_data.groupby(['Routes'])['Lead times'].mean().reset_index()

# Assuming you have the avg_lead_times_route DataFrame already defined
fig = px.bar(avg_lead_times_route, x='Routes', y='Lead times',
             labels={'Routes': 'Route', 'Lead times': 'Average Lead Time'},
             title='Average Lead Times by Route')

# Customize the color scale for bars
color_scale = px.colors.qualitative.Set3  # You can choose a different color scale
fig.update_traces(marker_color=color_scale)

# Customize the layout for beautification
fig.update_layout(
    title=dict(text='Average Lead Times by Route', x=0.5),
    xaxis_title='Route',
    yaxis_title='Average Lead Time',
    xaxis_tickangle=-45,  # Rotate x-axis labels for better readability
    font=dict(family="Arial", size=14),
    showlegend=False  # Remove legend
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2257fe19-d420-4324-bb22-393838cd1a65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2257fe19-d420-4324-bb22-393838cd1a65")) {                    Plotly.newPlot(                        "2257fe19-d420-4324-bb22-393838cd1a65",                        [{"alignmentgroup":"True","hovertemplate":"Route=%{x}\u003cbr\u003eAverage Lead Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)","rgb(179,222,105)","rgb(252,205,229)","rgb(217,217,217)","rgb(188,128,189)","rgb(204,235,197)","rgb(255,237,111)"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Route A","Route B","Route C"],"xaxis":"x","y":[14.69767441860465,17.216216216216218,16.35],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{" ...

# %%
best_route = avg_lead_times_route.loc[avg_lead_times_route['Lead times'].idxmin()]
best_route
# Out:
# Routes          Route A
# Lead times    14.697674
# Name: 0, dtype: object

# %%
best_route_data = supply_data[supply_data['Routes']==best_route['Routes']]
best_route_data.head()
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# 5      haircare   SKU5   1.699976            87                      147
# 6      skincare   SKU6   4.078333            48                       65
# 11     skincare  SKU11  90.635460            95                      960
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 3         7766.836426            Non-binary            23          13
# 4         2686.505152            Non-binary             5           3
# 5         2828.348746            Non-binary            90          27
# 6         7823.476560                  Male            11          15
# 11        6099.944116                Female            46          23
#
#     Order quantities  ...  Lead time Production volumes  \
# 3                 59  ...         24                937
# 4                 56  ...          5                414
# 5                 66  ...         10                104
# 6                 58  ...         14                314
# 11                60  ...         28                362
#
#     Manufacturing lead time Manufacturing costs Inspection results  \
# 3                        18           35.624741               Fail
# 4                         3           92.065161               Fail
# 5                        17           56.766476               Fail
# 6                        24            1.085069            Pending
# 11                       11           27.592363            Pending
#
#     Defect rates  Transportation modes   Routes       Costs   EOQ
# 3       4.746649                  Rail  Route A  254.776159  50.0
# 4       3.145580                   Air  Route A  923.440632  96.0
# 5       2.779194                  Road  Route A  235.461237  49.0
# 6       1.000911                   Sea  Route A  134.369097  37.0
# 11      0.021170                   Air  Route A  126.723033  36.0
#
# [5 rows x 25 columns]

# %% [markdown]
# **Modelling**
#
#
# Forecasting demand

# %%
X = supply_data.loc[:,['Price', 'Availability', 'Stock levels', 'Lead times', 'Order quantities']]
y = supply_data.loc[:,'Number of products sold']

# %%
# Define the number of folds for cross-validation
num_folds = 10

# %%
# Initialize lists to store evaluation metrics
mse_scores = []
rmse_scores = []
mae_scores = []
r2_scores = []

# %%
from sklearn.model_selection import KFold

# Create a KFold object
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
# Define the parameters for LightGBM
params = {
    'objective': 'regression',
    'metric': 'mean_squared_error',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

# %%
# !pip install lightgbm
# !pip install scikit-learn
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)

# %%
# !pip install --upgrade lightgbm
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.11.4)

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Define your LightGBM parameters
params = {
    'objective': 'regression',
    'metric': 'mse',
    'boosting_type': 'gbdt',
    # Add other parameters as needed
}

# Assuming you have X, y, and kf defined before this point

# Initialize lists to store scores
mse_scores = []
rmse_scores = []
mae_scores = []
r2_scores = []

for fold, (train_index, test_index) in enumerate(kf.split(X)):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Create LightGBM datasets for training and testing
    train_data = lgb.Dataset(X_train, label=y_train)
    test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)

    # Set the number of boosting rounds
    num_round = 100

    # Train the model with early stopping callback
    bst = lgb.train(
        params,
        train_data,
        num_round,
        valid_sets=[test_data],
        callbacks=[lgb.early_stopping(5, first_metric_only=True, verbose=True)]
    )

    # Make predictions on the test set
    y_pred = bst.predict(X_test, num_iteration=bst.best_iteration)

    # Calculate metrics
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Calculate the target range
    target_range = np.max(y_test) - np.min(y_test)

    # Calculate metrics as percentages
    percentage_mse = (mse / target_range) * 100
    percentage_rmse = (rmse / target_range) * 100
    percentage_mae = (mae / target_range) * 100
    percentage_r2 = (r2 * 100)

    # Append the scores to the respective lists
    mse_scores.append(percentage_mse)
    rmse_scores.append(percentage_rmse)
    mae_scores.append(percentage_mae)
    r2_scores.append(percentage_r2)

    print(f"Fold {fold + 1} - MSE: {percentage_mse:.2f}%, RMSE: {percentage_rmse:.2f}%, MAE: {percentage_mae:.2f}%, R2: {percentage_r2:.2f}%")
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000213 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 135
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 449.877778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 152995
# Evaluated only: l2
# Fold 1 - MSE: 15740.25%, RMSE: 40.24%, MAE: 38.59%, R2: -8.88%
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000029 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 137
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 465.177778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [2]	valid_0's l2: 42201.4
# Evaluated only: l2
# Fold 2 - MSE: 6003.04%, RMSE: 29.22%, MAE: 25.87%, R2: -3.26%
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000030 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 134
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 449.533333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [10]	valid_0's l2: 73480.8
# Evaluated only: l2
# Fold 3 - MSE: 8906.76%, RMSE: 32.86%, MAE: 24.66%, R2: -13.65%
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000031 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 134
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 462.877778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 95159.2
# Evaluated only: l2
# Fold 4 - MSE: 10177.45%, RMSE: 32.99%, MAE: 27.19%, R2: 0.18%
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000034 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 133
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 470.288889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 58621.5
# Evaluated only: l2
# Fold 5 - MSE: 8684.66%, RMSE: 35.87%, MAE: 32.87%, R2: -18.49%
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000033 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 136
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 473.155556
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 138837
# Evaluated only: l2
# Fold 6 - MSE: 15460.71%, RMSE: 41.49%, MAE: 40.66%, R2: -14.47%
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000035 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 136
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 464.577778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [2]	valid_0's l2: 76462
# Evaluated only: l2
# Fold 7 - MSE: 9593.72%, RMSE: 34.69%, MAE: 31.58%, R2: -1.37%
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000028 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 135
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 454.688889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 123188
# Evaluated only: l2
# Fold 8 - MSE: 12858.85%, RMSE: 36.64%, MAE: 32.98%, R2: -3.82%
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000029 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 136
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 459.822222
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 94315.2
# Evaluated only: l2
# Fold 9 - MSE: 9875.94%, RMSE: 32.16%, MAE: 28.65%, R2: 0.21%
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000028 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 135
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 459.900000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [18]	valid_0's l2: 56084.9
# Evaluated only: l2
# Fold 10 - MSE: 7360.22%, RMSE: 31.08%, MAE: 27.19%, R2: 16.38%

# %%
# Calculate the average scores over all folds
avg_mse = np.mean(mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_mae = np.mean(mae_scores)
avg_r2 = np.mean(r2_scores)

# Print the results
print(f"Average Mean Squared Error: {avg_mse:.2f}%")
print(f"Average Root Mean Squared Error: {avg_rmse:.2f}%")
print(f"Average Mean Absolute Error: {avg_mae:.2f}%")
print(f"Average R-squared: {avg_r2:.2f}%")
# Out:
# Average Mean Squared Error: 10466.16%
# Average Root Mean Squared Error: 34.72%
# Average Mean Absolute Error: 31.02%
# Average R-squared: -4.72%

# %% [markdown]
# **Cost optimization**

# %%
# Extract the features (X) and target (y)
X = supply_data.loc[:, 'Production volumes'].values.reshape(-1, 1)
y = supply_data.loc[:, 'Manufacturing costs'].values

# %%
# Define the number of folds for cross-validation
num_folds = 5

# %%
# Initialize lists to store evaluation metrics
mse_scores = []
rmse_scores = []
mae_scores = []
r2_scores = []

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize and fit the scaler to the data
scaler = MinMaxScaler()
scaler.fit(X)
# Out:
# MinMaxScaler()

# %%
# Create a KFold object
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Scale the data
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Define and compile the neural network model
    model = tf.keras.Sequential([
        Dense(64, activation='relu', input_dim=1),
        Dense(32, activation='relu'),
        Dense(1)
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')

    # Define Early Stopping callback
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Define Model Checkpoint callback to save the best model
    model_checkpoint = ModelCheckpoint('/kaggle/working/best_model.h5', save_best_only=True, save_weights_only=True, monitor='val_loss', mode='min')

    # Train the model on the training data with callbacks
    history = model.fit(X_train_scaled,
                        y_train, epochs=100,
                        batch_size=32,
                        validation_data=(X_test_scaled, y_test),
                        callbacks=[early_stopping, model_checkpoint])

    # Load the best model weights from the saved checkpoint
    model.load_weights('/kaggle/working/best_model.h5')

    # Make predictions on the test set
    y_pred = model.predict(X_test_scaled)

    # Calculate metrics
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(y_test - y_pred))
    r2 = r2_score(y_test, y_pred)

    # Calculate metrics as percentages
    target_range = np.max(y_test) - np.min(y_test)
    percentage_mse = (mse / target_range) * 100
    percentage_rmse = (rmse / target_range) * 100
    percentage_mae = (mae / target_range) * 100
    percentage_r2 = (r2 * 100)

    # Append the scores to the respective lists
    mse_scores.append(percentage_mse)
    rmse_scores.append(percentage_rmse)
    mae_scores.append(percentage_mae)
    r2_scores.append(percentage_r2)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s 118ms/step - loss: 2906.9502 - val_loss: 3706.5356
# Epoch 2/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2903.6670 - val_loss: 3703.0493
# Epoch 3/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2900.8333 - val_loss: 3699.3149
# Epoch 4/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2897.5554 - val_loss: 3695.5266
# Epoch 5/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2894.3506 - val_loss: 3691.7993
# Epoch 6/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2891.2219 - val_loss: 3688.2148
# Epoch 7/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2888.1685 - val_loss: 3684.3657
# Epoch 8/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2884.9731 - val_loss: 3680.2207
# Epoch 9/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2881.4519 - val_loss: 3675.8579
# Epoch 10/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2877.5435 - val_loss: 3671.2898
# Epoch 11/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2873.6577 - val_loss: 3666.5183
# Epoch 12/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2869.4226 - val_loss: 3661.4312
# Epoch 13/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2865.0352 - val_loss: 3655.9133
# Epoch 14/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2860.3884 - val_loss: 3649.9238
# Epoch 15/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2855.2239 - val_loss: 3643.5024
# Epoch 16/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2849.4731 - val_loss: 3636.6277
# Epoch 17/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2843.5742 - val_loss: 3629.1765
# Epoch 18/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2837.3713 - val_loss: 3621.1304
# Epoch 19/100
# 3/3 [==============================] - 0s 28ms/step - loss: 2830.4121 - val_loss: 3612.5562
# Epoch 20/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2823.1348 - val_loss: 3603.3562
# Epoch 21/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2815.1023 - val_loss: 3593.5403
# Epoch 22/100
# 3/3 [==============================] - 0s 37ms/step - loss: 2806.7100 - val_loss: 3582.9895
# Epoch 23/100
# 3/3 [==============================] - 0s 73ms/step - loss: 2797.9856 - val_loss: 3571.6108
# Epoch 24/100
# 3/3 [==============================] - 0s 38ms/step - loss: 2787.9973 - val_loss: 3559.5098
# Epoch 25/100
# 3/3 [==============================] - 0s 32ms/step - loss: 2777.6653 - val_loss: 3546.5847
# Epoch 26/100
# 3/3 [==============================] - 0s 41ms/step - loss: 2766.4246 - val_loss: 3532.8489
# Epoch 27/100
# 3/3 [==============================] - 0s 31ms/step - loss: 2754.9390 - val_loss: 3518.1399
# Epoch 28/100
# 3/3 [==============================] - 0s 30ms/step - loss: 2742.7944 - val_loss: 3502.4985
# Epoch 29/100
# 3/3 [==============================] - 0s 54ms/step - loss: 2728.6736 - val_loss: 3486.1008
# Epoch 30/100
# 3/3 [==============================] - 0s 50ms/step - loss: 2715.3188 - val_loss: 3468.4995
# Epoch 31/100
# 3/3 [==============================] - 0s 75ms/step - loss: 2699.8674 - val_loss: 3449.9773
# Epoch 32/100
# 3/3 [==============================] - 0s 39ms/step - loss: 2684.0598 - val_loss: 3430.2317
# Epoch 33/100
# 3/3 [==============================] - 0s 62ms/step - loss: 2667.3730 - val_loss: 3409.2085
# Epoch 34/100
# 3/3 [==============================] - 0s 77ms/step - loss: 2649.5725 - val_loss: 3386.9766
# Epoch 35/100
# 3/3 [==============================] - 0s 104ms/step - loss: 2630.9014 - val_loss: 3363.5610
# Epoch 36/100
# 3/3 [==============================] - 0s 96ms/step - loss: 2611.5945 - val_loss: 3338.9304
# Epoch 37/100
# 3/3 [==============================] - 0s 98ms/step - loss: 2589.8821 - val_loss: 3313.6414
# Epoch 38/100
# 3/3 [==============================] - 0s 95ms/step - loss: 2568.8694 - val_loss: 3286.9421
# Epoch 39/100
# 3/3 [==============================] - 0s 78ms/step - loss: 2546.8948 - val_loss: 3259.0098
# Epoch 40/100
# 3/3 [==============================] - 0s 63ms/step - loss: 2523.1294 - val_loss: 3230.1809
# Epoch 41/100
# 3/3 [==============================] - 0s 63ms/step - loss: 2499.5513 - val_loss: 3199.8735
# Epoch 42/100
# 3/3 [==============================] - 0s 71ms/step - loss: 2474.4353 - val_loss: 3168.4768
# Epoch 43/100
# 3/3 [==============================] - 0s 65ms/step - loss: 2447.7891 - val_loss: 3136.0857
# Epoch 44/100
# 3/3 [==============================] - 0s 76ms/step - loss: 2420.3796 - val_loss: 3102.4841
# Epoch 45/100
# 3/3 [==============================] - 0s 60ms/step - loss: 2391.7859 - val_loss: 3067.6353
# Epoch 46/100
# 3/3 [==============================] - 0s 71ms/step - loss: 2363.5527 - val_loss: 3031.2710
# Epoch 47/100
# 3/3 [==============================] - 0s 31ms/step - loss: 2333.3376 - val_loss: 2993.6340
# Epoch 48/100
# 3/3 [==============================] - 0s 29ms/step - loss: 2302.1863 - val_loss: 2954.8647
# Epoch 49/100
# 3/3 [==============================] - 0s 56ms/step - loss: 2269.4939 - val_loss: 2915.1372
# Epoch 50/100
# 3/3 [==============================] - 0s 51ms/step - loss: 2237.0796 - val_loss: 2873.8962
# Epoch 51/100
# 3/3 [==============================] - 0s 32ms/step - loss: 2204.1809 - val_loss: 2831.3013
# Epoch 52/100
# 3/3 [==============================] - 0s 47ms/step - loss: 2168.1084 - val_loss: 2787.8357
# Epoch 53/100
# 3/3 [==============================] - 0s 49ms/step - loss: 2134.5022 - val_loss: 2742.9634
# Epoch 54/100
# 3/3 [==============================] - 0s 35ms/step - loss: 2096.1248 - val_loss: 2698.1045
# Epoch 55/100
# 3/3 [==============================] - 0s 32ms/step - loss: 2060.2441 - val_loss: 2652.1304
# Epoch 56/100
# 3/3 [==============================] - 0s 75ms/step - loss: 2024.2090 - val_loss: 2605.2356
# Epoch 57/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1986.0222 - val_loss: 2558.3416
# Epoch 58/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1947.8236 - val_loss: 2511.0364
# Epoch 59/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1910.8785 - val_loss: 2462.7756
# Epoch 60/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1870.3076 - val_loss: 2414.2734
# Epoch 61/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1833.6960 - val_loss: 2364.0352
# Epoch 62/100
# 3/3 [==============================] - 0s 53ms/step - loss: 1796.2533 - val_loss: 2313.6306
# Epoch 63/100
# 3/3 [==============================] - 0s 64ms/step - loss: 1756.3109 - val_loss: 2264.0649
# Epoch 64/100
# 3/3 [==============================] - 0s 48ms/step - loss: 1717.6741 - val_loss: 2214.8999
# Epoch 65/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1677.4801 - val_loss: 2166.5459
# Epoch 66/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1641.5547 - val_loss: 2117.2437
# Epoch 67/100
# 3/3 [==============================] - 0s 77ms/step - loss: 1605.0729 - val_loss: 2067.9458
# Epoch 68/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1566.7205 - val_loss: 2019.7839
# Epoch 69/100
# 3/3 [==============================] - 0s 67ms/step - loss: 1531.9766 - val_loss: 1971.6969
# Epoch 70/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1494.2465 - val_loss: 1924.9512
# Epoch 71/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1457.4958 - val_loss: 1878.7523
# Epoch 72/100
# 3/3 [==============================] - 0s 48ms/step - loss: 1426.0487 - val_loss: 1831.6146
# Epoch 73/100
# 3/3 [==============================] - 0s 70ms/step - loss: 1390.0037 - val_loss: 1785.7522
# Epoch 74/100
# 3/3 [==============================] - 0s 54ms/step - loss: 1357.8450 - val_loss: 1739.8508
# Epoch 75/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1325.8186 - val_loss: 1695.2168
# Epoch 76/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1294.9609 - val_loss: 1652.2703
# Epoch 77/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1262.2542 - val_loss: 1611.1338
# Epoch 78/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1236.3571 - val_loss: 1569.6908
# Epoch 79/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1208.7175 - val_loss: 1529.9506
# Epoch 80/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1179.7334 - val_loss: 1492.6315
# Epoch 81/100
# 3/3 [==============================] - 0s 29ms/step - loss: 1155.7614 - val_loss: 1456.1735
# Epoch 82/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1133.2578 - val_loss: 1420.9998
# Epoch 83/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1110.6420 - val_loss: 1387.9418
# Epoch 84/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1089.3658 - val_loss: 1356.7904
# Epoch 85/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1070.5627 - val_loss: 1327.0482
# Epoch 86/100
# 3/3 [==============================] - 0s 28ms/step - loss: 1051.7180 - val_loss: 1298.6746
# Epoch 87/100
# 3/3 [==============================] - 0s 64ms/step - loss: 1035.7808 - val_loss: 1270.7988
# Epoch 88/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1019.0499 - val_loss: 1244.8362
# Epoch 89/100
# 3/3 [==============================] - 0s 52ms/step - loss: 1006.0708 - val_loss: 1220.0818
# Epoch 90/100
# 3/3 [==============================] - 0s 58ms/step - loss: 991.8268 - val_loss: 1197.7961
# Epoch 91/100
# 3/3 [==============================] - 0s 37ms/step - loss: 979.8912 - val_loss: 1177.0378
# Epoch 92/100
# 3/3 [==============================] - 0s 30ms/step - loss: 972.1273 - val_loss: 1156.6658
# Epoch 93/100
# 3/3 [==============================] - 0s 37ms/step - loss: 960.4742 - val_loss: 1139.2811
# Epoch 94/100
# 3/3 [==============================] - 0s 46ms/step - loss: 953.4528 - val_loss: 1123.3297
# Epoch 95/100
# 3/3 [==============================] - 0s 39ms/step - loss: 944.3391 - val_loss: 1109.6228
# Epoch 96/100
# 3/3 [==============================] - 0s 68ms/step - loss: 938.3581 - val_loss: 1096.3845
# Epoch 97/100
# 3/3 [==============================] - 0s 33ms/step - loss: 932.9198 - val_loss: 1083.9763
# Epoch 98/100
# 3/3 [==============================] - 0s 45ms/step - loss: 928.0206 - val_loss: 1072.4319
# Epoch 99/100
# 3/3 [==============================] - 0s 60ms/step - loss: 922.9017 - val_loss: 1061.7131
# Epoch 100/100
# 3/3 [==============================] - 0s 51ms/step - loss: 918.0479 - val_loss: 1051.5879
# 1/1 [==============================] - 0s 128ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 90ms/step - loss: 2960.7893 - val_loss: 3451.6594
# Epoch 2/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2955.8362 - val_loss: 3447.1328
# Epoch 3/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2951.4238 - val_loss: 3442.5142
# Epoch 4/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2946.9146 - val_loss: 3437.7786
# Epoch 5/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2942.2886 - val_loss: 3432.8743
# Epoch 6/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2937.4507 - val_loss: 3427.7681
# Epoch 7/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2932.5918 - val_loss: 3422.3835
# Epoch 8/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2927.4797 - val_loss: 3416.5691
# Epoch 9/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2921.6567 - val_loss: 3410.3335
# Epoch 10/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2915.4739 - val_loss: 3403.6138
# Epoch 11/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2909.1011 - val_loss: 3396.3418
# Epoch 12/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2902.2227 - val_loss: 3388.5312
# Epoch 13/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2894.5874 - val_loss: 3380.2078
# Epoch 14/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2886.7009 - val_loss: 3371.2507
# Epoch 15/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2878.0537 - val_loss: 3361.6414
# Epoch 16/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2868.6938 - val_loss: 3351.1960
# Epoch 17/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2858.9849 - val_loss: 3339.8828
# Epoch 18/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2847.6953 - val_loss: 3327.7964
# Epoch 19/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2836.4219 - val_loss: 3314.6704
# Epoch 20/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2823.1023 - val_loss: 3300.6523
# Epoch 21/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2810.0620 - val_loss: 3285.4102
# Epoch 22/100
# 3/3 [==============================] - 0s 31ms/step - loss: 2795.5515 - val_loss: 3269.0591
# Epoch 23/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2779.9243 - val_loss: 3251.5735
# Epoch 24/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2762.7085 - val_loss: 3232.9602
# Epoch 25/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2745.0083 - val_loss: 3213.0930
# Epoch 26/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2726.2451 - val_loss: 3191.9351
# Epoch 27/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2706.0234 - val_loss: 3169.4485
# Epoch 28/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2685.0991 - val_loss: 3145.5354
# Epoch 29/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2662.2065 - val_loss: 3120.2808
# Epoch 30/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2638.3271 - val_loss: 3093.5649
# Epoch 31/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2613.2043 - val_loss: 3065.4104
# Epoch 32/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2586.6465 - val_loss: 3035.8303
# Epoch 33/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2558.8391 - val_loss: 3004.7671
# Epoch 34/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2530.0591 - val_loss: 2972.1685
# Epoch 35/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2498.9722 - val_loss: 2938.1562
# Epoch 36/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2466.7222 - val_loss: 2902.5415
# Epoch 37/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2433.2273 - val_loss: 2865.1775
# Epoch 38/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2398.8284 - val_loss: 2826.0781
# Epoch 39/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2361.6899 - val_loss: 2785.7041
# Epoch 40/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2324.4424 - val_loss: 2743.6846
# Epoch 41/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2284.1362 - val_loss: 2700.3887
# Epoch 42/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2245.5327 - val_loss: 2655.1851
# Epoch 43/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2203.7104 - val_loss: 2608.8801
# Epoch 44/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2160.2859 - val_loss: 2561.4131
# Epoch 45/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2118.5508 - val_loss: 2512.4890
# Epoch 46/100
# 3/3 [==============================] - 0s 28ms/step - loss: 2073.7769 - val_loss: 2463.1792
# Epoch 47/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2028.0013 - val_loss: 2413.3218
# Epoch 48/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1982.8766 - val_loss: 2362.5813
# Epoch 49/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1936.6055 - val_loss: 2311.1567
# Epoch 50/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1890.3604 - val_loss: 2258.9580
# Epoch 51/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1843.8965 - val_loss: 2206.3110
# Epoch 52/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1795.4186 - val_loss: 2153.5737
# Epoch 53/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1747.8933 - val_loss: 2100.2390
# Epoch 54/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1702.3926 - val_loss: 2046.4636
# Epoch 55/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1652.7754 - val_loss: 1993.5914
# Epoch 56/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1604.3535 - val_loss: 1940.7770
# Epoch 57/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1560.4563 - val_loss: 1887.6051
# Epoch 58/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1511.9316 - val_loss: 1835.5944
# Epoch 59/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1473.2405 - val_loss: 1782.7965
# Epoch 60/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1425.4576 - val_loss: 1732.7054
# Epoch 61/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1378.4381 - val_loss: 1684.8718
# Epoch 62/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1342.4020 - val_loss: 1636.5251
# Epoch 63/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1299.8450 - val_loss: 1590.5957
# Epoch 64/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1261.5192 - val_loss: 1546.1750
# Epoch 65/100
# 3/3 [==============================] - 0s 29ms/step - loss: 1225.1169 - val_loss: 1503.0403
# Epoch 66/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1192.2838 - val_loss: 1461.1194
# Epoch 67/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1156.5205 - val_loss: 1422.1497
# Epoch 68/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1129.4138 - val_loss: 1384.3556
# Epoch 69/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1099.3143 - val_loss: 1349.6456
# Epoch 70/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1070.1113 - val_loss: 1317.9216
# Epoch 71/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1047.5095 - val_loss: 1287.3934
# Epoch 72/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1026.4283 - val_loss: 1258.6788
# Epoch 73/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1005.2449 - val_loss: 1232.6129
# Epoch 74/100
# 3/3 [==============================] - 0s 22ms/step - loss: 988.4639 - val_loss: 1208.3661
# Epoch 75/100
# 3/3 [==============================] - 0s 21ms/step - loss: 969.7464 - val_loss: 1186.8824
# Epoch 76/100
# 3/3 [==============================] - 0s 22ms/step - loss: 956.8421 - val_loss: 1167.1039
# Epoch 77/100
# 3/3 [==============================] - 0s 20ms/step - loss: 944.3027 - val_loss: 1149.4246
# Epoch 78/100
# 3/3 [==============================] - 0s 21ms/step - loss: 934.3591 - val_loss: 1133.2532
# Epoch 79/100
# 3/3 [==============================] - 0s 20ms/step - loss: 924.5228 - val_loss: 1119.0767
# Epoch 80/100
# 3/3 [==============================] - 0s 20ms/step - loss: 916.8838 - val_loss: 1106.6017
# Epoch 81/100
# 3/3 [==============================] - 0s 21ms/step - loss: 909.0745 - val_loss: 1096.0325
# Epoch 82/100
# 3/3 [==============================] - 0s 21ms/step - loss: 904.5350 - val_loss: 1086.1273
# Epoch 83/100
# 3/3 [==============================] - 0s 23ms/step - loss: 900.8250 - val_loss: 1077.4142
# Epoch 84/100
# 3/3 [==============================] - 0s 27ms/step - loss: 896.5262 - val_loss: 1070.2405
# Epoch 85/100
# 3/3 [==============================] - 0s 21ms/step - loss: 893.4802 - val_loss: 1063.7728
# Epoch 86/100
# 3/3 [==============================] - 0s 22ms/step - loss: 891.7130 - val_loss: 1057.8245
# Epoch 87/100
# 3/3 [==============================] - 0s 22ms/step - loss: 889.0621 - val_loss: 1052.6699
# Epoch 88/100
# 3/3 [==============================] - 0s 21ms/step - loss: 889.1365 - val_loss: 1047.4114
# Epoch 89/100
# 3/3 [==============================] - 0s 22ms/step - loss: 889.2248 - val_loss: 1043.0028
# Epoch 90/100
# 3/3 [==============================] - 0s 22ms/step - loss: 887.0280 - val_loss: 1040.0691
# Epoch 91/100
# 3/3 [==============================] - 0s 22ms/step - loss: 886.5083 - val_loss: 1037.6920
# Epoch 92/100
# 3/3 [==============================] - 0s 23ms/step - loss: 886.3801 - val_loss: 1035.6840
# Epoch 93/100
# 3/3 [==============================] - 0s 21ms/step - loss: 885.9528 - val_loss: 1034.2427
# Epoch 94/100
# 3/3 [==============================] - 0s 22ms/step - loss: 885.5089 - val_loss: 1033.3568
# Epoch 95/100
# 3/3 [==============================] - 0s 22ms/step - loss: 885.3301 - val_loss: 1032.2146
# Epoch 96/100
# 3/3 [==============================] - 0s 22ms/step - loss: 885.3289 - val_loss: 1030.7887
# Epoch 97/100
# 3/3 [==============================] - 0s 24ms/step - loss: 884.9414 - val_loss: 1029.6846
# Epoch 98/100
# 3/3 [==============================] - 0s 22ms/step - loss: 884.7210 - val_loss: 1028.7679
# Epoch 99/100
# 3/3 [==============================] - 0s 24ms/step - loss: 884.5148 - val_loss: 1028.0510
# Epoch 100/100
# 3/3 [==============================] - 0s 23ms/step - loss: 884.3589 - val_loss: 1027.3229
# 1/1 [==============================] - 0s 73ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 135ms/step - loss: 3189.2649 - val_loss: 2591.1226
# Epoch 2/100
# 3/3 [==============================] - 0s 39ms/step - loss: 3182.3970 - val_loss: 2585.9546
# Epoch 3/100
# 3/3 [==============================] - 0s 30ms/step - loss: 3176.4509 - val_loss: 2581.5918
# Epoch 4/100
# 3/3 [==============================] - 0s 27ms/step - loss: 3171.3296 - val_loss: 2577.4043
# Epoch 5/100
# 3/3 [==============================] - 0s 43ms/step - loss: 3166.1555 - val_loss: 2573.4692
# Epoch 6/100
# 3/3 [==============================] - 0s 38ms/step - loss: 3161.5649 - val_loss: 2569.4844
# Epoch 7/100
# 3/3 [==============================] - 0s 45ms/step - loss: 3156.7559 - val_loss: 2565.1423
# Epoch 8/100
# 3/3 [==============================] - 0s 29ms/step - loss: 3151.4448 - val_loss: 2560.4790
# Epoch 9/100
# 3/3 [==============================] - 0s 30ms/step - loss: 3145.6172 - val_loss: 2555.5303
# Epoch 10/100
# 3/3 [==============================] - 0s 44ms/step - loss: 3139.4790 - val_loss: 2550.1951
# Epoch 11/100
# 3/3 [==============================] - 0s 37ms/step - loss: 3133.0879 - val_loss: 2544.4102
# Epoch 12/100
# 3/3 [==============================] - 0s 32ms/step - loss: 3125.9224 - val_loss: 2538.1069
# Epoch 13/100
# 3/3 [==============================] - 0s 30ms/step - loss: 3118.0210 - val_loss: 2531.3606
# Epoch 14/100
# 3/3 [==============================] - 0s 43ms/step - loss: 3109.6523 - val_loss: 2524.0933
# Epoch 15/100
# 3/3 [==============================] - 0s 30ms/step - loss: 3100.6731 - val_loss: 2516.2134
# Epoch 16/100
# 3/3 [==============================] - 0s 38ms/step - loss: 3090.7891 - val_loss: 2507.5981
# Epoch 17/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3080.0852 - val_loss: 2498.0745
# Epoch 18/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3068.5625 - val_loss: 2487.6968
# Epoch 19/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3055.5686 - val_loss: 2476.2310
# Epoch 20/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3041.1296 - val_loss: 2463.8130
# Epoch 21/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3025.8101 - val_loss: 2450.4233
# Epoch 22/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3009.8706 - val_loss: 2436.0566
# Epoch 23/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2991.3020 - val_loss: 2420.8601
# Epoch 24/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2972.8359 - val_loss: 2404.5190
# Epoch 25/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2952.1873 - val_loss: 2387.1204
# Epoch 26/100
# 3/3 [==============================] - 0s 26ms/step - loss: 2930.2317 - val_loss: 2368.5520
# Epoch 27/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2907.2036 - val_loss: 2348.7727
# Epoch 28/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2883.6074 - val_loss: 2327.6919
# Epoch 29/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2856.9780 - val_loss: 2305.5679
# Epoch 30/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2829.4131 - val_loss: 2282.1497
# Epoch 31/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2799.2644 - val_loss: 2257.4204
# Epoch 32/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2769.1985 - val_loss: 2231.0786
# Epoch 33/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2736.8271 - val_loss: 2203.3811
# Epoch 34/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2701.8608 - val_loss: 2174.4199
# Epoch 35/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2666.7864 - val_loss: 2144.0925
# Epoch 36/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2628.5144 - val_loss: 2112.7690
# Epoch 37/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2587.1628 - val_loss: 2080.2839
# Epoch 38/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2549.0317 - val_loss: 2045.9680
# Epoch 39/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2505.6658 - val_loss: 2010.7936
# Epoch 40/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2461.5464 - val_loss: 1974.6516
# Epoch 41/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2415.0322 - val_loss: 1937.5681
# Epoch 42/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2368.1802 - val_loss: 1899.1693
# Epoch 43/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2317.6184 - val_loss: 1859.7260
# Epoch 44/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2269.4651 - val_loss: 1818.8145
# Epoch 45/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2217.0945 - val_loss: 1777.4703
# Epoch 46/100
# 3/3 [==============================] - 0s 26ms/step - loss: 2163.7329 - val_loss: 1735.7562
# Epoch 47/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2109.9556 - val_loss: 1693.5642
# Epoch 48/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2055.3682 - val_loss: 1651.2242
# Epoch 49/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2000.9785 - val_loss: 1609.0438
# Epoch 50/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1944.7727 - val_loss: 1567.2555
# Epoch 51/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1888.6746 - val_loss: 1525.3281
# Epoch 52/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1832.8762 - val_loss: 1483.3295
# Epoch 53/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1775.0730 - val_loss: 1441.7468
# Epoch 54/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1722.1556 - val_loss: 1400.4402
# Epoch 55/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1665.6285 - val_loss: 1360.6869
# Epoch 56/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1608.5146 - val_loss: 1322.4319
# Epoch 57/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1558.1448 - val_loss: 1285.0394
# Epoch 58/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1504.7711 - val_loss: 1249.6537
# Epoch 59/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1455.4480 - val_loss: 1216.1442
# Epoch 60/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1407.5178 - val_loss: 1184.9065
# Epoch 61/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1358.3368 - val_loss: 1156.3433
# Epoch 62/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1318.2439 - val_loss: 1129.2379
# Epoch 63/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1271.0732 - val_loss: 1104.9042
# Epoch 64/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1233.4902 - val_loss: 1082.0820
# Epoch 65/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1193.6667 - val_loss: 1061.6614
# Epoch 66/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1158.7394 - val_loss: 1043.2699
# Epoch 67/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1125.9265 - val_loss: 1027.0529
# Epoch 68/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1099.0560 - val_loss: 1013.1978
# Epoch 69/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1064.4963 - val_loss: 1002.4668
# Epoch 70/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1042.5012 - val_loss: 993.2737
# Epoch 71/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1021.7269 - val_loss: 986.0807
# Epoch 72/100
# 3/3 [==============================] - 0s 22ms/step - loss: 999.5261 - val_loss: 981.0721
# Epoch 73/100
# 3/3 [==============================] - 0s 21ms/step - loss: 982.1465 - val_loss: 977.7757
# Epoch 74/100
# 3/3 [==============================] - 0s 22ms/step - loss: 965.1866 - val_loss: 976.0812
# Epoch 75/100
# 3/3 [==============================] - 0s 24ms/step - loss: 953.7502 - val_loss: 975.7208
# Epoch 76/100
# 3/3 [==============================] - 0s 18ms/step - loss: 941.9798 - val_loss: 976.5240
# Epoch 77/100
# 3/3 [==============================] - 0s 19ms/step - loss: 933.2508 - val_loss: 978.2577
# Epoch 78/100
# 3/3 [==============================] - 0s 17ms/step - loss: 924.4301 - val_loss: 980.6551
# Epoch 79/100
# 3/3 [==============================] - 0s 18ms/step - loss: 918.5688 - val_loss: 983.5754
# Epoch 80/100
# 3/3 [==============================] - 0s 18ms/step - loss: 913.0804 - val_loss: 986.9089
# 1/1 [==============================] - 0s 58ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 97ms/step - loss: 3075.7336 - val_loss: 2984.0662
# Epoch 2/100
# 3/3 [==============================] - 0s 24ms/step - loss: 3070.9062 - val_loss: 2979.4075
# Epoch 3/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3066.2939 - val_loss: 2974.9844
# Epoch 4/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3061.6597 - val_loss: 2970.4929
# Epoch 5/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3057.0005 - val_loss: 2965.8132
# Epoch 6/100
# 3/3 [==============================] - 0s 43ms/step - loss: 3052.3735 - val_loss: 2960.8855
# Epoch 7/100
# 3/3 [==============================] - 0s 31ms/step - loss: 3047.3523 - val_loss: 2955.5649
# Epoch 8/100
# 3/3 [==============================] - 0s 40ms/step - loss: 3041.6235 - val_loss: 2949.8687
# Epoch 9/100
# 3/3 [==============================] - 0s 31ms/step - loss: 3035.7705 - val_loss: 2943.6318
# Epoch 10/100
# 3/3 [==============================] - 0s 34ms/step - loss: 3029.3064 - val_loss: 2936.8708
# Epoch 11/100
# 3/3 [==============================] - 0s 33ms/step - loss: 3022.6204 - val_loss: 2929.6589
# Epoch 12/100
# 3/3 [==============================] - 0s 27ms/step - loss: 3014.9238 - val_loss: 2922.0413
# Epoch 13/100
# 3/3 [==============================] - 0s 43ms/step - loss: 3007.1885 - val_loss: 2913.9243
# Epoch 14/100
# 3/3 [==============================] - 0s 46ms/step - loss: 2998.8218 - val_loss: 2905.2200
# Epoch 15/100
# 3/3 [==============================] - 0s 45ms/step - loss: 2989.8586 - val_loss: 2895.8879
# Epoch 16/100
# 3/3 [==============================] - 0s 31ms/step - loss: 2980.4185 - val_loss: 2885.9119
# Epoch 17/100
# 3/3 [==============================] - 0s 43ms/step - loss: 2970.2341 - val_loss: 2875.2661
# Epoch 18/100
# 3/3 [==============================] - 0s 31ms/step - loss: 2959.4382 - val_loss: 2863.9070
# Epoch 19/100
# 3/3 [==============================] - 0s 39ms/step - loss: 2947.4978 - val_loss: 2851.8015
# Epoch 20/100
# 3/3 [==============================] - 0s 40ms/step - loss: 2935.0708 - val_loss: 2838.7917
# Epoch 21/100
# 3/3 [==============================] - 0s 41ms/step - loss: 2921.9041 - val_loss: 2824.8411
# Epoch 22/100
# 3/3 [==============================] - 0s 39ms/step - loss: 2907.4197 - val_loss: 2809.9851
# Epoch 23/100
# 3/3 [==============================] - 0s 41ms/step - loss: 2892.2844 - val_loss: 2794.1138
# Epoch 24/100
# 3/3 [==============================] - 0s 43ms/step - loss: 2876.2539 - val_loss: 2777.1899
# Epoch 25/100
# 3/3 [==============================] - 0s 44ms/step - loss: 2858.5017 - val_loss: 2759.2810
# Epoch 26/100
# 3/3 [==============================] - 0s 48ms/step - loss: 2840.4526 - val_loss: 2740.1599
# Epoch 27/100
# 3/3 [==============================] - 0s 34ms/step - loss: 2820.4995 - val_loss: 2719.9746
# Epoch 28/100
# 3/3 [==============================] - 0s 43ms/step - loss: 2800.7107 - val_loss: 2698.4861
# Epoch 29/100
# 3/3 [==============================] - 0s 32ms/step - loss: 2777.1189 - val_loss: 2676.1167
# Epoch 30/100
# 3/3 [==============================] - 0s 47ms/step - loss: 2755.2104 - val_loss: 2652.1270
# Epoch 31/100
# 3/3 [==============================] - 0s 37ms/step - loss: 2730.6147 - val_loss: 2626.9312
# Epoch 32/100
# 3/3 [==============================] - 0s 32ms/step - loss: 2705.0789 - val_loss: 2600.4136
# Epoch 33/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2679.1384 - val_loss: 2572.4526
# Epoch 34/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2650.2671 - val_loss: 2543.5850
# Epoch 35/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2620.9275 - val_loss: 2513.5234
# Epoch 36/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2590.2737 - val_loss: 2482.1274
# Epoch 37/100
# 3/3 [==============================] - 0s 35ms/step - loss: 2558.2473 - val_loss: 2449.2898
# Epoch 38/100
# 3/3 [==============================] - 0s 34ms/step - loss: 2525.6931 - val_loss: 2414.9863
# Epoch 39/100
# 3/3 [==============================] - 0s 43ms/step - loss: 2490.5676 - val_loss: 2379.6890
# Epoch 40/100
# 3/3 [==============================] - 0s 44ms/step - loss: 2454.8472 - val_loss: 2343.2056
# Epoch 41/100
# 3/3 [==============================] - 0s 30ms/step - loss: 2419.4048 - val_loss: 2305.1597
# Epoch 42/100
# 3/3 [==============================] - 0s 34ms/step - loss: 2379.8921 - val_loss: 2266.0991
# Epoch 43/100
# 3/3 [==============================] - 0s 39ms/step - loss: 2340.6504 - val_loss: 2225.5581
# Epoch 44/100
# 3/3 [==============================] - 0s 35ms/step - loss: 2300.8357 - val_loss: 2183.6265
# Epoch 45/100
# 3/3 [==============================] - 0s 33ms/step - loss: 2257.2017 - val_loss: 2140.9399
# Epoch 46/100
# 3/3 [==============================] - 0s 28ms/step - loss: 2215.9102 - val_loss: 2096.8442
# Epoch 47/100
# 3/3 [==============================] - 0s 28ms/step - loss: 2170.8154 - val_loss: 2052.2935
# Epoch 48/100
# 3/3 [==============================] - 0s 27ms/step - loss: 2127.8577 - val_loss: 2006.6292
# Epoch 49/100
# 3/3 [==============================] - 0s 27ms/step - loss: 2082.6211 - val_loss: 1960.4509
# Epoch 50/100
# 3/3 [==============================] - 0s 26ms/step - loss: 2036.2855 - val_loss: 1913.9226
# Epoch 51/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1988.8119 - val_loss: 1866.8320
# Epoch 52/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1943.3811 - val_loss: 1818.5847
# Epoch 53/100
# 3/3 [==============================] - 0s 27ms/step - loss: 1898.6504 - val_loss: 1769.7012
# Epoch 54/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1850.4285 - val_loss: 1721.3123
# Epoch 55/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1802.4703 - val_loss: 1673.6292
# Epoch 56/100
# 3/3 [==============================] - 0s 28ms/step - loss: 1756.2465 - val_loss: 1625.9756
# Epoch 57/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1711.0613 - val_loss: 1578.4463
# Epoch 58/100
# 3/3 [==============================] - 0s 27ms/step - loss: 1661.8633 - val_loss: 1532.2745
# Epoch 59/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1619.5925 - val_loss: 1485.7141
# Epoch 60/100
# 3/3 [==============================] - 0s 27ms/step - loss: 1575.4308 - val_loss: 1440.0503
# Epoch 61/100
# 3/3 [==============================] - 0s 27ms/step - loss: 1529.6738 - val_loss: 1395.5162
# Epoch 62/100
# 3/3 [==============================] - 0s 27ms/step - loss: 1488.0017 - val_loss: 1351.1707
# Epoch 63/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1447.4763 - val_loss: 1307.4478
# Epoch 64/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1406.6332 - val_loss: 1265.1125
# Epoch 65/100
# 3/3 [==============================] - 0s 44ms/step - loss: 1368.4512 - val_loss: 1224.6210
# Epoch 66/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1331.9877 - val_loss: 1186.5077
# Epoch 67/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1293.8461 - val_loss: 1150.8943
# Epoch 68/100
# 3/3 [==============================] - 0s 44ms/step - loss: 1264.6667 - val_loss: 1116.3010
# Epoch 69/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1230.2617 - val_loss: 1084.6819
# Epoch 70/100
# 3/3 [==============================] - 0s 27ms/step - loss: 1203.6595 - val_loss: 1053.6091
# Epoch 71/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1177.0021 - val_loss: 1024.5046
# Epoch 72/100
# 3/3 [==============================] - 0s 29ms/step - loss: 1152.1757 - val_loss: 997.3356
# Epoch 73/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1130.7968 - val_loss: 972.3758
# Epoch 74/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1107.2272 - val_loss: 950.5186
# Epoch 75/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1087.9209 - val_loss: 930.4135
# Epoch 76/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1072.8917 - val_loss: 910.9911
# Epoch 77/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1055.7006 - val_loss: 893.4740
# Epoch 78/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1042.5466 - val_loss: 876.9701
# Epoch 79/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1027.1771 - val_loss: 862.7013
# Epoch 80/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1015.4141 - val_loss: 849.3708
# Epoch 81/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1006.7889 - val_loss: 836.3869
# Epoch 82/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1000.1508 - val_loss: 824.9746
# Epoch 83/100
# 3/3 [==============================] - 0s 25ms/step - loss: 989.4244 - val_loss: 816.1569
# Epoch 84/100
# 3/3 [==============================] - 0s 21ms/step - loss: 984.5573 - val_loss: 807.6624
# Epoch 85/100
# 3/3 [==============================] - 0s 29ms/step - loss: 977.7365 - val_loss: 800.6591
# Epoch 86/100
# 3/3 [==============================] - 0s 23ms/step - loss: 973.7487 - val_loss: 794.5682
# Epoch 87/100
# 3/3 [==============================] - 0s 23ms/step - loss: 969.9572 - val_loss: 789.5583
# Epoch 88/100
# 3/3 [==============================] - 0s 25ms/step - loss: 966.2733 - val_loss: 785.3241
# Epoch 89/100
# 3/3 [==============================] - 0s 22ms/step - loss: 962.7479 - val_loss: 781.8672
# Epoch 90/100
# 3/3 [==============================] - 0s 23ms/step - loss: 961.4203 - val_loss: 778.1843
# Epoch 91/100
# 3/3 [==============================] - 0s 22ms/step - loss: 959.8700 - val_loss: 774.9937
# Epoch 92/100
# 3/3 [==============================] - 0s 22ms/step - loss: 956.7884 - val_loss: 772.7637
# Epoch 93/100
# 3/3 [==============================] - 0s 21ms/step - loss: 955.5018 - val_loss: 770.3917
# Epoch 94/100
# 3/3 [==============================] - 0s 33ms/step - loss: 953.8318 - val_loss: 768.2177
# Epoch 95/100
# 3/3 [==============================] - 0s 21ms/step - loss: 952.9062 - val_loss: 766.0204
# Epoch 96/100
# 3/3 [==============================] - 0s 25ms/step - loss: 951.6676 - val_loss: 764.0052
# Epoch 97/100
# 3/3 [==============================] - 0s 23ms/step - loss: 950.3151 - val_loss: 762.0809
# Epoch 98/100
# 3/3 [==============================] - 0s 24ms/step - loss: 949.0482 - val_loss: 760.0734
# Epoch 99/100
# 3/3 [==============================] - 0s 20ms/step - loss: 948.3253 - val_loss: 758.0406
# Epoch 100/100
# 3/3 [==============================] - 0s 24ms/step - loss: 948.9305 - val_loss: 756.3114
# 1/1 [==============================] - 0s 73ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 90ms/step - loss: 3185.8423 - val_loss: 2566.4263
# Epoch 2/100
# 3/3 [==============================] - 0s 25ms/step - loss: 3180.8425 - val_loss: 2561.8176
# Epoch 3/100
# 3/3 [==============================] - 0s 24ms/step - loss: 3176.1335 - val_loss: 2557.1968
# Epoch 4/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3171.4526 - val_loss: 2552.3960
# Epoch 5/100
# 3/3 [==============================] - 0s 25ms/step - loss: 3166.4810 - val_loss: 2547.4822
# Epoch 6/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3161.2761 - val_loss: 2542.3113
# Epoch 7/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3156.0012 - val_loss: 2536.8782
# Epoch 8/100
# 3/3 [==============================] - 0s 25ms/step - loss: 3150.0120 - val_loss: 2531.1914
# Epoch 9/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3144.1030 - val_loss: 2525.1479
# Epoch 10/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3137.7791 - val_loss: 2518.7087
# Epoch 11/100
# 3/3 [==============================] - 0s 25ms/step - loss: 3130.7778 - val_loss: 2511.9326
# Epoch 12/100
# 3/3 [==============================] - 0s 24ms/step - loss: 3123.5691 - val_loss: 2504.7043
# Epoch 13/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3115.8621 - val_loss: 2496.9790
# Epoch 14/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3107.7561 - val_loss: 2488.6919
# Epoch 15/100
# 3/3 [==============================] - 0s 26ms/step - loss: 3098.8616 - val_loss: 2479.8633
# Epoch 16/100
# 3/3 [==============================] - 0s 26ms/step - loss: 3089.4038 - val_loss: 2470.4431
# Epoch 17/100
# 3/3 [==============================] - 0s 24ms/step - loss: 3079.3970 - val_loss: 2460.3560
# Epoch 18/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3068.5200 - val_loss: 2449.5872
# Epoch 19/100
# 3/3 [==============================] - 0s 28ms/step - loss: 3057.0854 - val_loss: 2438.0679
# Epoch 20/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3044.3044 - val_loss: 2425.8406
# Epoch 21/100
# 3/3 [==============================] - 0s 24ms/step - loss: 3031.2175 - val_loss: 2412.7358
# Epoch 22/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3018.0005 - val_loss: 2398.7627
# Epoch 23/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3002.0886 - val_loss: 2384.1479
# Epoch 24/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2986.1831 - val_loss: 2368.5430
# Epoch 25/100
# 3/3 [==============================] - 0s 26ms/step - loss: 2969.3784 - val_loss: 2351.9402
# Epoch 26/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2951.2100 - val_loss: 2334.3801
# Epoch 27/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2932.7073 - val_loss: 2315.6682
# Epoch 28/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2912.4263 - val_loss: 2296.0110
# Epoch 29/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2890.2681 - val_loss: 2275.4519
# Epoch 30/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2868.4529 - val_loss: 2253.5781
# Epoch 31/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2845.2886 - val_loss: 2230.5442
# Epoch 32/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2819.5620 - val_loss: 2206.5793
# Epoch 33/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2793.8064 - val_loss: 2181.4331
# Epoch 34/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2765.8591 - val_loss: 2155.3647
# Epoch 35/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2738.4700 - val_loss: 2127.9858
# Epoch 36/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2707.6758 - val_loss: 2099.7761
# Epoch 37/100
# 3/3 [==============================] - 0s 29ms/step - loss: 2677.3813 - val_loss: 2070.5164
# Epoch 38/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2644.9285 - val_loss: 2040.3818
# Epoch 39/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2610.0852 - val_loss: 2009.3787
# Epoch 40/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2577.4861 - val_loss: 1976.7086
# Epoch 41/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2539.6799 - val_loss: 1943.3724
# Epoch 42/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2503.5933 - val_loss: 1908.7500
# Epoch 43/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2465.0317 - val_loss: 1873.4186
# Epoch 44/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2425.7832 - val_loss: 1837.3988
# Epoch 45/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2384.7078 - val_loss: 1800.7943
# Epoch 46/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2345.1377 - val_loss: 1763.2035
# Epoch 47/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2300.4568 - val_loss: 1725.4226
# Epoch 48/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2259.2468 - val_loss: 1686.5316
# Epoch 49/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2215.0093 - val_loss: 1647.3118
# Epoch 50/100
# 3/3 [==============================] - 0s 26ms/step - loss: 2169.4878 - val_loss: 1607.8622
# Epoch 51/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2122.6731 - val_loss: 1568.0823
# Epoch 52/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2077.5500 - val_loss: 1527.8002
# Epoch 53/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2030.9473 - val_loss: 1487.5559
# Epoch 54/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1983.9711 - val_loss: 1447.4641
# Epoch 55/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1936.7600 - val_loss: 1407.3655
# Epoch 56/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1890.5905 - val_loss: 1367.7393
# Epoch 57/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1841.3938 - val_loss: 1329.2981
# Epoch 58/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1794.5989 - val_loss: 1291.0671
# Epoch 59/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1747.8480 - val_loss: 1253.3416
# Epoch 60/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1701.7959 - val_loss: 1216.1428
# Epoch 61/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1655.8646 - val_loss: 1179.7753
# Epoch 62/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1608.0974 - val_loss: 1144.6063
# Epoch 63/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1563.3180 - val_loss: 1110.4443
# Epoch 64/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1523.1421 - val_loss: 1077.5496
# Epoch 65/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1478.3219 - val_loss: 1047.1072
# Epoch 66/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1435.5867 - val_loss: 1018.4453
# Epoch 67/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1396.9749 - val_loss: 991.3810
# Epoch 68/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1358.6716 - val_loss: 966.1194
# Epoch 69/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1321.9164 - val_loss: 942.3950
# Epoch 70/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1289.0261 - val_loss: 920.1293
# Epoch 71/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1253.6107 - val_loss: 900.0958
# Epoch 72/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1223.1166 - val_loss: 881.7674
# Epoch 73/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1191.7004 - val_loss: 865.6240
# Epoch 74/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1163.4305 - val_loss: 851.4945
# Epoch 75/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1137.3837 - val_loss: 839.2877
# Epoch 76/100
# 3/3 [==============================] - 0s 27ms/step - loss: 1113.1902 - val_loss: 828.7658
# Epoch 77/100
# 3/3 [==============================] - 0s 28ms/step - loss: 1089.4438 - val_loss: 820.0584
# Epoch 78/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1071.3953 - val_loss: 812.9614
# Epoch 79/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1051.2490 - val_loss: 807.7806
# Epoch 80/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1035.2347 - val_loss: 804.1360
# Epoch 81/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1017.5573 - val_loss: 801.8619
# Epoch 82/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1003.8413 - val_loss: 800.7241
# Epoch 83/100
# 3/3 [==============================] - 0s 35ms/step - loss: 994.8314 - val_loss: 800.7316
# Epoch 84/100
# 3/3 [==============================] - 0s 25ms/step - loss: 982.5140 - val_loss: 801.7426
# Epoch 85/100
# 3/3 [==============================] - 0s 32ms/step - loss: 971.9498 - val_loss: 803.5338
# Epoch 86/100
# 3/3 [==============================] - 0s 42ms/step - loss: 965.5586 - val_loss: 806.1564
# Epoch 87/100
# 3/3 [==============================] - 0s 31ms/step - loss: 956.7322 - val_loss: 809.2911
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x79eba591e710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 84ms/step

# %%
# Calculate the average scores over all folds
avg_mse = np.mean(mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_mae = np.mean(mae_scores)
avg_r2 = np.mean(r2_scores)

# Print the results
print(f"Average Mean Squared Error: {avg_mse:.2f}%")
print(f"Average Root Mean Squared Error: {avg_rmse:.2f}%")
print(f"Average Mean Absolute Error: {avg_mae:.2f}%")
print(f"Average R-squared: {avg_r2:.2f}%")
# Out:
# Average Mean Squared Error: 979.46%
# Average Root Mean Squared Error: 32.16%
# Average Mean Absolute Error: 27.27%
# Average R-squared: -16.05%

# %%
# Find the most optimal production volume to minimize manufacturing cost
min_production_volume = supply_data['Production volumes'].min()
max_production_volume = 1000
step_size = 100

cheapest_cost = float('inf')
best_production_volume = None

for production_volume in range(min_production_volume, max_production_volume + 1, step_size):
    normalized_production_volume = scaler.transform(np.array([[production_volume]]))
    predicted_cost = model.predict(normalized_production_volume)

    if predicted_cost[0][0] < cheapest_cost:
        cheapest_cost = predicted_cost[0][0]
        best_production_volume = production_volume

print('Most optimal production volume to minimize manufacturing cost:', best_production_volume)
print('The cheapest manufacturing cost:', cheapest_cost)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# Most optimal production volume to minimize manufacturing cost: 104
# The cheapest manufacturing cost: 22.805906
