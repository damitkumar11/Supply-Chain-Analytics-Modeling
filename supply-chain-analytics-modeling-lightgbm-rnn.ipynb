# %% [markdown]
# # Introduction
#
# In this supply chain analytics analysis, we encountered the challenge of working with a dataset consisting of 100 rows and 24 columns. During the Exploratory Data Analysis phase, we conducted quality control checks, assessed supply chain risks, performed Inventory Optimization Analysis using the Economic Order Quantity (EOQ) method, conducted customer segmentation analysis, and explored lead times optimization. However, in the modeling phase, we found that using LightGBM and RNN models was not suitable for this small dataset, resulting in unsatisfactory outcomes. Therefore, we recommend utilizing a larger dataset or considering alternatives such as linear regression, decision trees, or random forests to achieve better results in cost optimization and demand forecasting.In this supply chain analytics analysis, we encountered the challenge of working with a dataset consisting of 100 rows and 24 columns. During the Exploratory Data Analysis phase, we conducted quality control checks, assessed supply chain risks, performed Inventory Optimization Analysis using the Economic Order Quantity (EOQ) method, conducted customer segmentation analysis, and explored lead times optimization. However, in the modeling phase, we found that using LightGBM and RNN models was not suitable for this small dataset, resulting in unsatisfactory outcomes. Therefore, we recommend utilizing a larger dataset or considering alternatives such as linear regression, decision trees, or random forests to achieve better results in cost optimization and demand forecasting.

# %% [markdown]
# # Load data

# %%
# Disable warning

import warnings

warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
import pandas as pd

supply_data = pd.read_csv("/kaggle/input/supply-chain-analysis/supply_chain_data.csv")

# %%
supply_data.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# 2                88  ...    Mumbai        12                 971
# 3                59  ...   Kolkata        24                 937
# 4                56  ...     Delhi         5                 414
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                      29           46.279879             Pending
# 1                      30           33.616769             Pending
# 2                      27           30.688019             Pending
# 3                      18           35.624741                Fail
# 4                       3           92.065161                Fail
#
#    Defect rates  Transportation modes   Routes       Costs
# 0      0.226410                  Road  Route B  187.752075
# 1      4.854068                  Road  Route B  503.065579
# 2      4.580593                   Air  Route C  141.920282
# 3      4.746649                  Rail  Route A  254.776159
# 4      3.145580                   Air  Route A  923.440632
#
# [5 rows x 24 columns]

# %%
supply_data.shape
# Out:
# (100, 24)

# %%
supply_data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %% [markdown]
# **Feature explanation**
#
# - **Product Type**: The type of product associated with specific data in the supply chain.
# - **SKU (Stock Keeping Unit)**: Unique code used to identify a particular product.
# - **Price**: The price of the product or item in the supply chain.
# - **Availability**: Information about product availability.
# - **Number of Products Sold**: The number of products that have been sold in a certain time period.
# - **Revenue Generated**: Total revenue generated from product sales in a certain time period.
# - **Customer demographics**: Information about customer characteristics, such as age, gender, geographic location, etc.
# - **Stock Levels**: The number of products still available in stock at any given time.
# - **Lead Times**: The time required to order or receive products from suppliers.
# - **Order Quantities**: The number of products ordered in one order or shipment.
# - **Shipping Times**: The time required to ship products from the warehouse or distribution center to customers.
# - **Shipping Carriers**: Companies or services used to ship products to customers.
# - **Shipping Costs**: Costs associated with shipping products, including delivery fees and additional fees.
# - **Supplier Name**: Name of supplier or vendor who provides products or materials to the company.
# - **Location**: The physical location associated with the data in the supply chain, such as the location of a warehouse or distribution center.
# - **Lead Time**: The time required to obtain products or materials from a particular supplier.
# - **Production Volumes**: The number of products produced in a certain time period.
# - **Manufacturing Lead Time**: The time required to produce a product, from ordering materials until the product is ready.
# - **Manufacturing Costs**: Costs related to the production process, including raw material costs, labor, etc.
# - **Inspection Results**: Results of product or material quality inspection.
# - **Defect Rates**: The level of defects or defects in the products produced.
# - **Transportation Modes**: The transportation mode used to send products, such as land, sea or air.
# - **Routes**: Routes or paths used to send products from one point to another in the supply chain.
# - **Costs**: Costs related to various aspects of the supply chain, including transportation costs, production costs, and other costs.

# %%
supply_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
#  14  Location                 100 non-null    object
#  15  Lead time                100 non-null    int64
#  16  Production volumes       100 non-null    int64
#  17  Manufacturing lead time  100 non-null    int64
#  18  Manufacturing costs      100 non-null    float64
#  19  Inspection results       100 non-null    object
#  20  Defect rates             100 non-null    float64
#  21  Transportation modes     100 non-null    object
#  22  Routes                   100 non-null    object
#  23  Costs                    100 non-null    float64
# dtypes: float64(6), int64(9), object(9)
# memory usage: 18.9+ KB

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ### Checking for missing values

# %%
# Check for missing values
missing_values = supply_data.isnull().sum()

# Display columns with missing values and the count of missing values
missing_values = missing_values[missing_values > 0]

if not missing_values.empty:
    print("Columns with missing values:")
    for column, count in missing_values.items():
        print(f"{column}: {count} missing values")
else:
    print("There are no columns with missing value")
# Out:
# There are no columns with missing value

# %% [markdown]
# ### Check for duplicate data

# %%
if supply_data.duplicated().any():
    print(f"There are as many as {supply_data.duplicated().sum()} duplicate data.")
else:
    print("There are no duplicate data.")
# Out:
# There are no duplicate data.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Quality control check

# %%
import plotly.express as px

defect_rates_by_product = supply_data.groupby("Product type")['Defect rates'].mean().reset_index()

# Create a bar chart using Plotly
fig = px.bar(defect_rates_by_product, x='Product type', y='Defect rates', title='Defect Rates by Product Type')

# Customize the color scale for bars
color_scale = px.colors.qualitative.Set3  # You can choose a different color scale
fig.update_traces(marker_color=color_scale)

# Customize the appearance of the chart
fig.update_layout(
    xaxis_title="Product Type",
    yaxis_title="Mean Defect Rates",
    xaxis=dict(categoryorder='total descending'),
    yaxis=dict(title='Mean Defect Rates'),
    plot_bgcolor='white',
    title_x=0.5,
    showlegend=True  # Hide the legend
)

# Show the plot
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="ce0740a6-c590-4661-b93e-ae49e4d6f1f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce0740a6-c590-4661-b93e-ae49e4d6f1f7")) {                    Plotly.newPlot(                        "ce0740a6-c590-4661-b93e-ae49e4d6f1f7",                        [{"alignmentgroup":"True","hovertemplate":"Product type=%{x}\u003cbr\u003eDefect rates=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)","rgb(179,222,105)","rgb(252,205,229)","rgb(217,217,217)","rgb(188,128,189)","rgb(204,235,197)","rgb(255,237,111)"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["cosmetics","haircare","skincare"],"xaxis":"x","y":[1.9192869782813182,2.4831501929246245,2.334680781980237],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5 ...

# %% [markdown]
# ### Supply chain risk assessment

# %%
risk_data = supply_data[['SKU', 'Lead times', 'Stock levels']]
risk_data.head()
# Out:
#     SKU  Lead times  Stock levels
# 0  SKU0           7            58
# 1  SKU1          30            53
# 2  SKU2          10             1
# 3  SKU3          13            23
# 4  SKU4           3             5

# %%
risk_data['Risk score'] = risk_data['Lead times'] * (1-risk_data.loc[:,'Stock levels'])

# %%
# Sort the risk_data by 'Risk score' in descending order and select top 10 highest-risk data
risk_data = risk_data.sort_values(by='Risk score', ascending=False)[:10]

# Create a bar plot using Plotly Express
fig = px.bar(risk_data, x='SKU', y='Risk score', title='Top 10 Highest-Risk Data',
             labels={'Risk score': 'Risk Score', 'SKU': 'SKU'},
             text='Risk score')

# Customize the appearance of the plot
fig.update_traces(texttemplate='%{text:.2f}', textposition='outside')
fig.update_layout(xaxis_title='SKU', yaxis_title='Risk Score', title_x=0.5)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="dcfea526-3625-45f6-b714-70f92261c004" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dcfea526-3625-45f6-b714-70f92261c004")) {                    Plotly.newPlot(                        "dcfea526-3625-45f6-b714-70f92261c004",                        [{"alignmentgroup":"True","hovertemplate":"SKU=%{x}\u003cbr\u003eRisk Score=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[8.0,0.0,0.0,-5.0,-12.0,-16.0,-28.0,-37.0,-40.0,-45.0],"textposition":"outside","x":["SKU68","SKU2","SKU34","SKU16","SKU4","SKU78","SKU87","SKU76","SKU8","SKU47"],"xaxis":"x","y":[8,0,0,-5,-12,-16,-28,-37,-40,-45],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay ...

# %% [markdown]
# ### Inventory Optimization Analysis with EOQ

# %%
# we assume for holding cost 0.2
holdingcost = 0.2

# %%
import numpy as np

def calculate_eoq(data):
    S = data['Costs']
    D = data['Number of products sold'] 
    H = data['Number of products sold'] * holdingcost
    EOQ = np.sqrt((2*S*D)/H)
    return round(EOQ)

# %%
supply_data['EOQ'] = calculate_eoq(supply_data)

# %%
comparison_columns = supply_data[['SKU', 'EOQ','Order quantities']]
comparison_columns.head()
# Out:
#     SKU   EOQ  Order quantities
# 0  SKU0  43.0                96
# 1  SKU1  71.0                37
# 2  SKU2  38.0                88
# 3  SKU3  50.0                59
# 4  SKU4  96.0                56

# %%
# Extracting the top 10 rows for comparison
top_10_comparison = comparison_columns.head(10)

# Creating a bar plot to compare EOQ and Order Quantities for the top 10 SKUs
fig = px.bar(top_10_comparison, x='SKU', y=['EOQ', 'Order quantities'], 
             title='Comparison of EOQ and Order Quantities for Top 10 SKUs')

fig.update_layout(
    title_x=0.5
)

# Displaying the plot
fig.show()
# Out:
# <div>                            <div id="0c8915de-0387-499b-bb49-48516d5d073e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c8915de-0387-499b-bb49-48516d5d073e")) {                    Plotly.newPlot(                        "0c8915de-0387-499b-bb49-48516d5d073e",                        [{"alignmentgroup":"True","hovertemplate":"variable=EOQ\u003cbr\u003eSKU=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EOQ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"EOQ","offsetgroup":"EOQ","orientation":"v","showlegend":true,"textposition":"auto","x":["SKU0","SKU1","SKU2","SKU3","SKU4","SKU5","SKU6","SKU7","SKU8","SKU9"],"xaxis":"x","y":[43.0,71.0,38.0,50.0,96.0,49.0,37.0,90.0,71.0,100.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Order quantities\u003cbr\u003eSKU=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Order quantities","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Order quantities","offsetgroup":"Order quantities","orientation":"v","showlegend":true,"textposition":"auto","x":["SKU0","SKU1","SKU2","SKU3","SKU4","SKU5","SKU6","SKU7","SKU8","SKU9"],"xaxis":"x","y":[96.0,37.0,88.0,59.0,56.0,66.0,58.0,11.0,15.0,83.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mes ...

# %% [markdown]
# ### Customer segmentation analysis

# %%
revenue_avg_by_demo_prod = supply_data.groupby(['Customer demographics', 'Product type'])['Revenue generated'].mean().reset_index()
revenue_sum_by_demo_prod = supply_data.groupby(['Customer demographics', 'Product type'])['Revenue generated'].sum().reset_index()

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Create a palette of different colors for each product type
colors = px.colors.qualitative.Set3

# Create a subplot with 1 row and 2 columns
fig = make_subplots(rows=1, cols=2, subplot_titles=('Average Revenue', 'Total Revenue'))

# Plot for average revenue
for i, product_type in enumerate(revenue_avg_by_demo_prod['Product type'].unique()):
    subset = revenue_avg_by_demo_prod[revenue_avg_by_demo_prod['Product type'] == product_type]
    fig.add_trace(
        go.Bar(
            x=subset['Customer demographics'],
            y=subset['Revenue generated'],
            name=product_type,
            marker_color=colors[i]
        ),
        row=1, col=1
    )

# Plot for total revenue without legend
for i, product_type in enumerate(revenue_sum_by_demo_prod['Product type'].unique()):
    subset = revenue_sum_by_demo_prod[revenue_sum_by_demo_prod['Product type'] == product_type]
    fig.add_trace(
        go.Bar(
            x=subset['Customer demographics'],
            y=subset['Revenue generated'],
            showlegend=False,  # Hide legend for this subplot
            marker_color=colors[i]
        ),
        row=1, col=2
    )

# Beautify the subplot and show the legend for the first subplot
fig.update_layout(
    title='Revenue Analysis by Customer Demographics and Product Type',
    xaxis=dict(title='Customer Demographics'),
    yaxis=dict(title='Revenue'),
    xaxis2=dict(title='Customer Demographics'),
    yaxis2=dict(title='Revenue'),
    title_x=0.5,
    showlegend=True  # Show legend for the first subplot
)

# Show the subplot
fig.show()
# Out:
# <div>                            <div id="ceb4ad55-26d1-4061-b698-77c4b94aea70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ceb4ad55-26d1-4061-b698-77c4b94aea70")) {                    Plotly.newPlot(                        "ceb4ad55-26d1-4061-b698-77c4b94aea70",                        [{"marker":{"color":"rgb(141,211,199)"},"name":"cosmetics","x":["Female","Male","Non-binary","Unknown"],"y":[6954.854219685358,5347.7413743343,5247.096332116826,6335.182377815462],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(255,255,179)"},"name":"haircare","x":["Female","Male","Non-binary","Unknown"],"y":[6362.416641586338,5059.992730921369,5567.306726391122,4810.63219522254],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(190,186,218)"},"name":"skincare","x":["Female","Male","Non-binary","Unknown"],"y":[6095.470280123415,7806.214493320447,4650.8338885715775,6287.152695992038],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(141,211,199)"},"showlegend":false,"x":["Female","Male","Non-binary","Unknown"],"y":[69548.54219685358,21390.9654973372,26235.48166058413,44346.27664470823],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"rgb(255,255,179)"},"showlegend":false,"x":["Female","Male","Non-binary","Unknown"],"y":[12724.833283172677,50599.927309213694,38971.14708473785,72159.4829283381],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"rgb(190,186,218)"},"showlegend":false,"x":["Female","Male","Non-binary","Unknown"],"y":[79241.1136416044,54643.50145324313,51159.17277428735,56584.374263928345],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"color ...

# %% [markdown]
# ### Lead times optimization analysis

# %%
avg_lead_times_transport = supply_data.groupby(['Transportation modes'])['Lead times'].mean().reset_index()

fig = px.bar(avg_lead_times_transport, x='Transportation modes', y='Lead times',
             labels={'Transportation modes': 'Transportation Mode', 'Lead times': 'Average Lead Time'},
             title='Average Lead Times by Transportation Mode')

# Customize the color scale for bars
color_scale = px.colors.qualitative.Set3  # You can choose a different color scale
fig.update_traces(marker_color=color_scale)

# Customize the layout for beautification
fig.update_layout(
    title=dict(text='Average Lead Times by Transportation Mode', x=0.5),
    xaxis_title='Transportation Mode',
    yaxis_title='Average Lead Time',
    xaxis_tickangle=-45,  # Rotate x-axis labels for better readability
    font=dict(family="Arial", size=14),
    showlegend=False  # Remove legend
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="4790ea94-3abe-49d1-bb08-ebd27bac7c34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4790ea94-3abe-49d1-bb08-ebd27bac7c34")) {                    Plotly.newPlot(                        "4790ea94-3abe-49d1-bb08-ebd27bac7c34",                        [{"alignmentgroup":"True","hovertemplate":"Transportation Mode=%{x}\u003cbr\u003eAverage Lead Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)","rgb(179,222,105)","rgb(252,205,229)","rgb(217,217,217)","rgb(188,128,189)","rgb(204,235,197)","rgb(255,237,111)"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Air","Rail","Road","Sea"],"xaxis":"x","y":[18.26923076923077,14.892857142857142,17.137931034482758,12.176470588235293],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"er ...

# %%
best_transportation_mode = avg_lead_times_transport.loc[avg_lead_times_transport['Lead times'].idxmin()]
best_transportation_mode
# Out:
# Transportation modes          Sea
# Lead times              12.176471
# Name: 3, dtype: object

# %%
best_transportation_data = supply_data[supply_data['Transportation modes']==best_transportation_mode['Transportation modes']]
best_transportation_data.head()
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 6      skincare   SKU6   4.078333            48                       65
# 8     cosmetics   SKU8  68.717597            78                      150
# 15     skincare  SKU15  36.989245            94                      469
# 18     haircare  SKU18  36.443628            23                      620
# 27    cosmetics  SKU27  92.557361            42                      352
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 6         7823.476560                  Male            11          15
# 8         7517.363211                Female             5          10
# 15        5442.086785            Non-binary             9           8
# 18        9364.673505               Unknown            10          10
# 27        2686.457224               Unknown            47           9
#
#     Order quantities  ...  Lead time Production volumes  \
# 6                 58  ...         14                314
# 8                 15  ...         13                769
# 15                69  ...         14                580
# 18                46  ...         18                374
# 27                62  ...         25                291
#
#     Manufacturing lead time Manufacturing costs Inspection results  \
# 6                        24            1.085069            Pending
# 8                         8           11.423027            Pending
# 15                        7           97.121282               Pass
# 18                       17           27.107981            Pending
# 27                        4           10.528245               Fail
#
#     Defect rates  Transportation modes   Routes       Costs   EOQ
# 6       1.000911                   Sea  Route A  134.369097  37.0
# 8       2.709863                   Sea  Route B  505.557134  71.0
# 15      2.264406                   Sea  Route B  127.861800  36.0
# 18      2.231939                   Sea  Route A  593.480259  77.0
# 27      2.864668                   Sea  Route B  762.459182  87.0
#
# [5 rows x 25 columns]

# %%
import plotly.express as px

avg_lead_times_route = supply_data.groupby(['Routes'])['Lead times'].mean().reset_index()

# Assuming you have the avg_lead_times_route DataFrame already defined
fig = px.bar(avg_lead_times_route, x='Routes', y='Lead times',
             labels={'Routes': 'Route', 'Lead times': 'Average Lead Time'},
             title='Average Lead Times by Route')

# Customize the color scale for bars
color_scale = px.colors.qualitative.Set3  # You can choose a different color scale
fig.update_traces(marker_color=color_scale)

# Customize the layout for beautification
fig.update_layout(
    title=dict(text='Average Lead Times by Route', x=0.5),
    xaxis_title='Route',
    yaxis_title='Average Lead Time',
    xaxis_tickangle=-45,  # Rotate x-axis labels for better readability
    font=dict(family="Arial", size=14),
    showlegend=False  # Remove legend
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="5797b2a2-d880-4ce9-867e-6fb34c6ea15a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5797b2a2-d880-4ce9-867e-6fb34c6ea15a")) {                    Plotly.newPlot(                        "5797b2a2-d880-4ce9-867e-6fb34c6ea15a",                        [{"alignmentgroup":"True","hovertemplate":"Route=%{x}\u003cbr\u003eAverage Lead Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)","rgb(179,222,105)","rgb(252,205,229)","rgb(217,217,217)","rgb(188,128,189)","rgb(204,235,197)","rgb(255,237,111)"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Route A","Route B","Route C"],"xaxis":"x","y":[14.69767441860465,17.216216216216218,16.35],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"col ...

# %%
best_route = avg_lead_times_route.loc[avg_lead_times_route['Lead times'].idxmin()]
best_route
# Out:
# Routes          Route A
# Lead times    14.697674
# Name: 0, dtype: object

# %%
best_route_data = supply_data[supply_data['Routes']==best_route['Routes']]
best_route_data.head()
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# 5      haircare   SKU5   1.699976            87                      147
# 6      skincare   SKU6   4.078333            48                       65
# 11     skincare  SKU11  90.635460            95                      960
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 3         7766.836426            Non-binary            23          13
# 4         2686.505152            Non-binary             5           3
# 5         2828.348746            Non-binary            90          27
# 6         7823.476560                  Male            11          15
# 11        6099.944116                Female            46          23
#
#     Order quantities  ...  Lead time Production volumes  \
# 3                 59  ...         24                937
# 4                 56  ...          5                414
# 5                 66  ...         10                104
# 6                 58  ...         14                314
# 11                60  ...         28                362
#
#     Manufacturing lead time Manufacturing costs Inspection results  \
# 3                        18           35.624741               Fail
# 4                         3           92.065161               Fail
# 5                        17           56.766476               Fail
# 6                        24            1.085069            Pending
# 11                       11           27.592363            Pending
#
#     Defect rates  Transportation modes   Routes       Costs   EOQ
# 3       4.746649                  Rail  Route A  254.776159  50.0
# 4       3.145580                   Air  Route A  923.440632  96.0
# 5       2.779194                  Road  Route A  235.461237  49.0
# 6       1.000911                   Sea  Route A  134.369097  37.0
# 11      0.021170                   Air  Route A  126.723033  36.0
#
# [5 rows x 25 columns]

# %% [markdown]
# # Modelling

# %% [markdown]
# ### Forecasting demand

# %%
X = supply_data.loc[:,['Price', 'Availability', 'Stock levels', 'Lead times', 'Order quantities']]
y = supply_data.loc[:,'Number of products sold']

# %%
# Define the number of folds for cross-validation
num_folds = 10

# %%
# Initialize lists to store evaluation metrics
mse_scores = []
rmse_scores = []
mae_scores = []
r2_scores = []

# %%
from sklearn.model_selection import KFold

# Create a KFold object
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
# Define the parameters for LightGBM
params = {
    'objective': 'regression',
    'metric': 'mean_squared_error',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Create LightGBM datasets for training and testing
    train_data = lgb.Dataset(X_train, label=y_train)
    test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)
    
    # Add early stopping
    num_round = 100  # Increase the number of boosting rounds
    early_stopping_rounds = 5  # Set the number of rounds to wait for early stopping

    # Train the model with early stopping
    bst = lgb.train(
        params,
        train_data,
        num_round,
        valid_sets=[test_data],
        early_stopping_rounds=early_stopping_rounds,
        verbose_eval=10
    )
    
    # Make predictions on the test set
    y_pred = bst.predict(X_test, num_iteration=bst.best_iteration)

    # Calculate metrics
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Calculate the target range
    target_range = np.max(y_test) - np.min(y_test)

    # Calculate metrics as percentages
    percentage_mse = (mse / target_range) * 100
    percentage_rmse = (rmse / target_range) * 100
    percentage_mae = (mae / target_range) * 100
    percentage_r2 = (r2 * 100)

    # Append the scores to the respective lists
    mse_scores.append(percentage_mse)
    rmse_scores.append(percentage_rmse)
    mae_scores.append(percentage_mae)
    r2_scores.append(percentage_r2)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002918 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 135
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 449.877778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 152909
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000371 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 137
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 465.177778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [3]	valid_0's l2: 42338.7
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000321 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 134
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 449.533333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 75638.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [14]	valid_0's l2: 75013.7
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000324 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 134
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 462.877778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 95404.3
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000400 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 133
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 470.288889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 58352.6
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000309 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 136
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 473.155556
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 137452
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000328 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 136
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 464.577778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [4]	valid_0's l2: 76462.3
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000369 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 135
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 454.688889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 122894
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000305 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 136
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 459.822222
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [2]	valid_0's l2: 94322.5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000334 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 135
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 459.900000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 62553.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's l2: 59845.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's l2: 57732.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's l2: 56213.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's l2: 55133.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's l2: 55135.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [57]	valid_0's l2: 54910.1

# %%
# Calculate the average scores over all folds
avg_mse = np.mean(mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_mae = np.mean(mae_scores)
avg_r2 = np.mean(r2_scores)

# Print the results
print(f"Average Mean Squared Error: {avg_mse:.2f}%")
print(f"Average Root Mean Squared Error: {avg_rmse:.2f}%")
print(f"Average Mean Absolute Error: {avg_mae:.2f}%")
print(f"Average R-squared: {avg_r2:.2f}%")
# Out:
# Average Mean Squared Error: 10450.61%
# Average Root Mean Squared Error: 34.70%
# Average Mean Absolute Error: 31.02%
# Average R-squared: -4.64%

# %% [markdown]
# ### Cost optimization

# %%
# Extract the features (X) and target (y)
X = supply_data.loc[:, 'Production volumes'].values.reshape(-1, 1)
y = supply_data.loc[:, 'Manufacturing costs'].values

# %%
# Define the number of folds for cross-validation
num_folds = 5

# %%
# Initialize lists to store evaluation metrics
mse_scores = []
rmse_scores = []
mae_scores = []
r2_scores = []

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize and fit the scaler to the data
scaler = MinMaxScaler()
scaler.fit(X)
# Out:
# MinMaxScaler()

# %%
# Create a KFold object
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Scale the data
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Define and compile the neural network model
    model = tf.keras.Sequential([
        Dense(64, activation='relu', input_dim=1),
        Dense(32, activation='relu'),
        Dense(1)
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    
    # Define Early Stopping callback
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Define Model Checkpoint callback to save the best model
    model_checkpoint = ModelCheckpoint('/kaggle/working/best_model.h5', save_best_only=True, save_weights_only=True, monitor='val_loss', mode='min')

    # Train the model on the training data with callbacks
    history = model.fit(X_train_scaled,
                        y_train, epochs=100,
                        batch_size=32,
                        validation_data=(X_test_scaled, y_test),
                        callbacks=[early_stopping, model_checkpoint])

    # Load the best model weights from the saved checkpoint
    model.load_weights('/kaggle/working/best_model.h5')
    
    # Make predictions on the test set
    y_pred = model.predict(X_test_scaled)
    
    # Calculate metrics
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(y_test - y_pred))
    r2 = r2_score(y_test, y_pred)

    # Calculate metrics as percentages
    target_range = np.max(y_test) - np.min(y_test)
    percentage_mse = (mse / target_range) * 100
    percentage_rmse = (rmse / target_range) * 100
    percentage_mae = (mae / target_range) * 100
    percentage_r2 = (r2 * 100)

    # Append the scores to the respective lists
    mse_scores.append(percentage_mse)
    rmse_scores.append(percentage_rmse)
    mae_scores.append(percentage_mae)
    r2_scores.append(percentage_r2)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s 116ms/step - loss: 2903.2122 - val_loss: 3698.8804
# Epoch 2/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2896.3394 - val_loss: 3691.1433
# Epoch 3/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2889.5227 - val_loss: 3683.7727
# Epoch 4/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2883.6016 - val_loss: 3676.3052
# Epoch 5/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2877.2673 - val_loss: 3668.5786
# Epoch 6/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2870.4292 - val_loss: 3660.4934
# Epoch 7/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2863.9910 - val_loss: 3652.1426
# Epoch 8/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2856.4331 - val_loss: 3643.6667
# Epoch 9/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2849.2852 - val_loss: 3634.7742
# Epoch 10/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2841.5664 - val_loss: 3625.3706
# Epoch 11/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2833.4160 - val_loss: 3615.2852
# Epoch 12/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2824.9907 - val_loss: 3604.4136
# Epoch 13/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2815.5112 - val_loss: 3592.7554
# Epoch 14/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2805.4792 - val_loss: 3580.3013
# Epoch 15/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2795.0288 - val_loss: 3566.9539
# Epoch 16/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2783.5266 - val_loss: 3552.6531
# Epoch 17/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2771.6199 - val_loss: 3537.2876
# Epoch 18/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2757.9038 - val_loss: 3521.0078
# Epoch 19/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2743.8892 - val_loss: 3503.4539
# Epoch 20/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2729.1428 - val_loss: 3484.5364
# Epoch 21/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2713.3003 - val_loss: 3464.2896
# Epoch 22/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2696.0056 - val_loss: 3442.7983
# Epoch 23/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2677.4285 - val_loss: 3419.9812
# Epoch 24/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2658.2231 - val_loss: 3395.5415
# Epoch 25/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2637.2561 - val_loss: 3369.5339
# Epoch 26/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2614.3379 - val_loss: 3341.9583
# Epoch 27/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2591.8298 - val_loss: 3312.2937
# Epoch 28/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2565.7854 - val_loss: 3281.1323
# Epoch 29/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2540.8816 - val_loss: 3247.9504
# Epoch 30/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2512.3311 - val_loss: 3213.4675
# Epoch 31/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2482.8618 - val_loss: 3177.2744
# Epoch 32/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2452.0637 - val_loss: 3139.0776
# Epoch 33/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2420.2141 - val_loss: 3098.8599
# Epoch 34/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2387.5498 - val_loss: 3056.6631
# Epoch 35/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2353.5547 - val_loss: 3012.8308
# Epoch 36/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2315.8738 - val_loss: 2967.8816
# Epoch 37/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2279.7383 - val_loss: 2921.1304
# Epoch 38/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2239.9771 - val_loss: 2873.1614
# Epoch 39/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2200.6921 - val_loss: 2823.1204
# Epoch 40/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2158.8892 - val_loss: 2771.6199
# Epoch 41/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2116.9546 - val_loss: 2718.3228
# Epoch 42/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2073.4653 - val_loss: 2663.5386
# Epoch 43/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2031.2527 - val_loss: 2607.1301
# Epoch 44/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1985.3539 - val_loss: 2549.8862
# Epoch 45/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1940.4078 - val_loss: 2491.9407
# Epoch 46/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1892.6318 - val_loss: 2434.3989
# Epoch 47/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1848.9509 - val_loss: 2375.2822
# Epoch 48/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1800.4000 - val_loss: 2316.2422
# Epoch 49/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1753.6174 - val_loss: 2256.3384
# Epoch 50/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1708.0183 - val_loss: 2195.5547
# Epoch 51/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1661.5725 - val_loss: 2134.3098
# Epoch 52/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1614.5110 - val_loss: 2073.5125
# Epoch 53/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1567.9047 - val_loss: 2013.5164
# Epoch 54/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1522.9237 - val_loss: 1953.8601
# Epoch 55/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1479.7345 - val_loss: 1894.6165
# Epoch 56/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1435.4264 - val_loss: 1837.1537
# Epoch 57/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1395.2994 - val_loss: 1780.6855
# Epoch 58/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1350.1725 - val_loss: 1726.7949
# Epoch 59/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1315.3168 - val_loss: 1672.5508
# Epoch 60/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1275.1017 - val_loss: 1620.4570
# Epoch 61/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1240.7814 - val_loss: 1569.0315
# Epoch 62/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1205.4705 - val_loss: 1519.8929
# Epoch 63/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1172.3002 - val_loss: 1472.8092
# Epoch 64/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1142.2874 - val_loss: 1427.9929
# Epoch 65/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1113.5459 - val_loss: 1386.1843
# Epoch 66/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1088.3076 - val_loss: 1346.3060
# Epoch 67/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1065.2747 - val_loss: 1308.7629
# Epoch 68/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1041.1082 - val_loss: 1274.2643
# Epoch 69/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1022.9479 - val_loss: 1241.4449
# Epoch 70/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1002.7053 - val_loss: 1211.2601
# Epoch 71/100
# 3/3 [==============================] - 0s 20ms/step - loss: 991.5168 - val_loss: 1181.7500
# Epoch 72/100
# 3/3 [==============================] - 0s 20ms/step - loss: 974.9662 - val_loss: 1156.3759
# Epoch 73/100
# 3/3 [==============================] - 0s 19ms/step - loss: 963.6544 - val_loss: 1133.2195
# Epoch 74/100
# 3/3 [==============================] - 0s 19ms/step - loss: 953.7705 - val_loss: 1112.8298
# Epoch 75/100
# 3/3 [==============================] - 0s 19ms/step - loss: 944.1561 - val_loss: 1094.5426
# Epoch 76/100
# 3/3 [==============================] - 0s 20ms/step - loss: 935.8550 - val_loss: 1078.3693
# Epoch 77/100
# 3/3 [==============================] - 0s 19ms/step - loss: 930.4676 - val_loss: 1063.8708
# Epoch 78/100
# 3/3 [==============================] - 0s 19ms/step - loss: 925.4222 - val_loss: 1050.8899
# Epoch 79/100
# 3/3 [==============================] - 0s 19ms/step - loss: 921.2754 - val_loss: 1039.5144
# Epoch 80/100
# 3/3 [==============================] - 0s 20ms/step - loss: 917.4084 - val_loss: 1029.7195
# Epoch 81/100
# 3/3 [==============================] - 0s 20ms/step - loss: 915.3161 - val_loss: 1020.9154
# Epoch 82/100
# 3/3 [==============================] - 0s 21ms/step - loss: 913.2456 - val_loss: 1013.6333
# Epoch 83/100
# 3/3 [==============================] - 0s 19ms/step - loss: 911.9407 - val_loss: 1008.1765
# Epoch 84/100
# 3/3 [==============================] - 0s 19ms/step - loss: 909.7936 - val_loss: 1004.6923
# Epoch 85/100
# 3/3 [==============================] - 0s 19ms/step - loss: 908.3391 - val_loss: 1002.3185
# Epoch 86/100
# 3/3 [==============================] - 0s 19ms/step - loss: 907.6229 - val_loss: 999.0179
# Epoch 87/100
# 3/3 [==============================] - 0s 21ms/step - loss: 906.6987 - val_loss: 995.3830
# Epoch 88/100
# 3/3 [==============================] - 0s 20ms/step - loss: 906.1400 - val_loss: 990.9011
# Epoch 89/100
# 3/3 [==============================] - 0s 20ms/step - loss: 905.5695 - val_loss: 987.1497
# Epoch 90/100
# 3/3 [==============================] - 0s 21ms/step - loss: 904.3957 - val_loss: 984.7536
# Epoch 91/100
# 3/3 [==============================] - 0s 20ms/step - loss: 903.7643 - val_loss: 982.5936
# Epoch 92/100
# 3/3 [==============================] - 0s 20ms/step - loss: 903.2497 - val_loss: 979.9758
# Epoch 93/100
# 3/3 [==============================] - 0s 19ms/step - loss: 903.8710 - val_loss: 976.5867
# Epoch 94/100
# 3/3 [==============================] - 0s 19ms/step - loss: 902.4758 - val_loss: 975.2048
# Epoch 95/100
# 3/3 [==============================] - 0s 19ms/step - loss: 901.8361 - val_loss: 974.9189
# Epoch 96/100
# 3/3 [==============================] - 0s 20ms/step - loss: 901.5454 - val_loss: 974.0231
# Epoch 97/100
# 3/3 [==============================] - 0s 15ms/step - loss: 901.2568 - val_loss: 974.2127
# Epoch 98/100
# 3/3 [==============================] - 0s 16ms/step - loss: 900.9212 - val_loss: 974.7805
# Epoch 99/100
# 3/3 [==============================] - 0s 16ms/step - loss: 900.5607 - val_loss: 974.3529
# Epoch 100/100
# 3/3 [==============================] - 0s 19ms/step - loss: 900.2496 - val_loss: 973.2186
# 1/1 [==============================] - 0s 106ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 83ms/step - loss: 2970.7207 - val_loss: 3460.5969
# Epoch 2/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2964.8416 - val_loss: 3454.7500
# Epoch 3/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2958.9858 - val_loss: 3449.0188
# Epoch 4/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2953.4688 - val_loss: 3443.2429
# Epoch 5/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2947.8394 - val_loss: 3437.3882
# Epoch 6/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2941.7849 - val_loss: 3431.4597
# Epoch 7/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2936.3892 - val_loss: 3425.4133
# Epoch 8/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2930.2961 - val_loss: 3419.3809
# Epoch 9/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2924.4011 - val_loss: 3413.3677
# Epoch 10/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2918.6445 - val_loss: 3407.0430
# Epoch 11/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2912.6328 - val_loss: 3400.4707
# Epoch 12/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2906.3906 - val_loss: 3393.6978
# Epoch 13/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2899.7075 - val_loss: 3386.6152
# Epoch 14/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2892.7029 - val_loss: 3379.1453
# Epoch 15/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2885.4214 - val_loss: 3371.1782
# Epoch 16/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2878.1509 - val_loss: 3362.7629
# Epoch 17/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2870.0405 - val_loss: 3353.9128
# Epoch 18/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2861.4290 - val_loss: 3344.5312
# Epoch 19/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2852.4312 - val_loss: 3334.5281
# Epoch 20/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2842.6660 - val_loss: 3323.8745
# Epoch 21/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2832.3562 - val_loss: 3312.4805
# Epoch 22/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2822.0176 - val_loss: 3300.2788
# Epoch 23/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2809.7368 - val_loss: 3287.4966
# Epoch 24/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2798.1731 - val_loss: 3273.7451
# Epoch 25/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2784.6812 - val_loss: 3259.3665
# Epoch 26/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2771.6648 - val_loss: 3244.0994
# Epoch 27/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2756.6392 - val_loss: 3228.2063
# Epoch 28/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2741.3657 - val_loss: 3211.4419
# Epoch 29/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2725.0273 - val_loss: 3193.7136
# Epoch 30/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2708.8711 - val_loss: 3174.7063
# Epoch 31/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2690.6211 - val_loss: 3154.7339
# Epoch 32/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2671.5986 - val_loss: 3133.6462
# Epoch 33/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2651.4119 - val_loss: 3111.5430
# Epoch 34/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2630.9385 - val_loss: 3088.1951
# Epoch 35/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2609.0229 - val_loss: 3063.8303
# Epoch 36/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2585.2144 - val_loss: 3038.5166
# Epoch 37/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2562.2034 - val_loss: 3011.6636
# Epoch 38/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2536.0105 - val_loss: 2983.7429
# Epoch 39/100
# 3/3 [==============================] - 0s 27ms/step - loss: 2509.6194 - val_loss: 2954.4714
# Epoch 40/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2482.6003 - val_loss: 2923.7495
# Epoch 41/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2453.6809 - val_loss: 2891.9175
# Epoch 42/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2423.9626 - val_loss: 2859.1624
# Epoch 43/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2393.5669 - val_loss: 2825.3088
# Epoch 44/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2361.7480 - val_loss: 2790.4285
# Epoch 45/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2328.5959 - val_loss: 2754.1763
# Epoch 46/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2294.5945 - val_loss: 2716.5532
# Epoch 47/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2262.9346 - val_loss: 2677.3589
# Epoch 48/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2225.6838 - val_loss: 2637.9622
# Epoch 49/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2188.5999 - val_loss: 2597.6838
# Epoch 50/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2151.5955 - val_loss: 2556.3550
# Epoch 51/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2113.8215 - val_loss: 2513.9673
# Epoch 52/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2074.8496 - val_loss: 2470.1399
# Epoch 53/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2033.7406 - val_loss: 2425.0979
# Epoch 54/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1992.8020 - val_loss: 2378.6255
# Epoch 55/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1952.1667 - val_loss: 2331.2847
# Epoch 56/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1906.2522 - val_loss: 2284.0715
# Epoch 57/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1862.7471 - val_loss: 2235.7937
# Epoch 58/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1823.5729 - val_loss: 2185.9719
# Epoch 59/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1777.7035 - val_loss: 2136.9644
# Epoch 60/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1732.8961 - val_loss: 2088.1746
# Epoch 61/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1689.5455 - val_loss: 2039.0950
# Epoch 62/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1648.9612 - val_loss: 1989.3665
# Epoch 63/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1603.3190 - val_loss: 1940.7933
# Epoch 64/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1558.8391 - val_loss: 1892.7307
# Epoch 65/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1516.8597 - val_loss: 1844.5394
# Epoch 66/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1477.6316 - val_loss: 1796.4495
# Epoch 67/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1435.5140 - val_loss: 1749.9822
# Epoch 68/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1395.4479 - val_loss: 1704.3972
# Epoch 69/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1355.5582 - val_loss: 1659.9066
# Epoch 70/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1321.0089 - val_loss: 1615.8896
# Epoch 71/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1282.4263 - val_loss: 1574.3507
# Epoch 72/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1249.4880 - val_loss: 1533.6508
# Epoch 73/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1216.4299 - val_loss: 1495.0399
# Epoch 74/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1185.9625 - val_loss: 1458.3611
# Epoch 75/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1155.8610 - val_loss: 1423.8682
# Epoch 76/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1127.5442 - val_loss: 1391.2219
# Epoch 77/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1102.2986 - val_loss: 1359.6299
# Epoch 78/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1078.2999 - val_loss: 1329.2338
# Epoch 79/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1053.4641 - val_loss: 1300.9771
# Epoch 80/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1035.8595 - val_loss: 1273.3035
# Epoch 81/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1014.2977 - val_loss: 1248.8669
# Epoch 82/100
# 3/3 [==============================] - 0s 20ms/step - loss: 997.0441 - val_loss: 1226.6125
# Epoch 83/100
# 3/3 [==============================] - 0s 21ms/step - loss: 981.9791 - val_loss: 1205.6075
# Epoch 84/100
# 3/3 [==============================] - 0s 19ms/step - loss: 967.5189 - val_loss: 1185.9432
# Epoch 85/100
# 3/3 [==============================] - 0s 19ms/step - loss: 954.6115 - val_loss: 1167.8967
# Epoch 86/100
# 3/3 [==============================] - 0s 19ms/step - loss: 945.0456 - val_loss: 1151.2615
# Epoch 87/100
# 3/3 [==============================] - 0s 20ms/step - loss: 935.2238 - val_loss: 1136.8982
# Epoch 88/100
# 3/3 [==============================] - 0s 21ms/step - loss: 926.5529 - val_loss: 1124.6055
# Epoch 89/100
# 3/3 [==============================] - 0s 19ms/step - loss: 918.7589 - val_loss: 1113.9897
# Epoch 90/100
# 3/3 [==============================] - 0s 21ms/step - loss: 914.5394 - val_loss: 1103.8918
# Epoch 91/100
# 3/3 [==============================] - 0s 19ms/step - loss: 908.7504 - val_loss: 1095.3663
# Epoch 92/100
# 3/3 [==============================] - 0s 19ms/step - loss: 905.3254 - val_loss: 1087.9216
# Epoch 93/100
# 3/3 [==============================] - 0s 19ms/step - loss: 901.2355 - val_loss: 1081.6738
# Epoch 94/100
# 3/3 [==============================] - 0s 21ms/step - loss: 898.8221 - val_loss: 1075.5214
# Epoch 95/100
# 3/3 [==============================] - 0s 20ms/step - loss: 896.1195 - val_loss: 1070.0184
# Epoch 96/100
# 3/3 [==============================] - 0s 19ms/step - loss: 893.1555 - val_loss: 1065.0043
# Epoch 97/100
# 3/3 [==============================] - 0s 20ms/step - loss: 893.2074 - val_loss: 1059.4064
# Epoch 98/100
# 3/3 [==============================] - 0s 20ms/step - loss: 890.5491 - val_loss: 1055.2346
# Epoch 99/100
# 3/3 [==============================] - 0s 19ms/step - loss: 889.3882 - val_loss: 1051.5122
# Epoch 100/100
# 3/3 [==============================] - 0s 19ms/step - loss: 890.3089 - val_loss: 1047.7554
# 1/1 [==============================] - 0s 59ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 84ms/step - loss: 3181.4744 - val_loss: 2585.0769
# Epoch 2/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3175.2256 - val_loss: 2580.3191
# Epoch 3/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3169.7734 - val_loss: 2575.4011
# Epoch 4/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3163.4634 - val_loss: 2569.8201
# Epoch 5/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3156.6785 - val_loss: 2563.9758
# Epoch 6/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3149.5071 - val_loss: 2557.9973
# Epoch 7/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3142.2329 - val_loss: 2551.9478
# Epoch 8/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3134.4009 - val_loss: 2545.6204
# Epoch 9/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3127.1829 - val_loss: 2538.8586
# Epoch 10/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3118.9331 - val_loss: 2531.7546
# Epoch 11/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3110.3918 - val_loss: 2524.2393
# Epoch 12/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3101.0054 - val_loss: 2516.3142
# Epoch 13/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3091.0598 - val_loss: 2507.8804
# Epoch 14/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3080.4377 - val_loss: 2498.7612
# Epoch 15/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3069.8518 - val_loss: 2488.7766
# Epoch 16/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3056.9924 - val_loss: 2478.1953
# Epoch 17/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3044.3044 - val_loss: 2466.7334
# Epoch 18/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3030.2429 - val_loss: 2454.4893
# Epoch 19/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3015.1848 - val_loss: 2441.3940
# Epoch 20/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2998.3328 - val_loss: 2427.4272
# Epoch 21/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2981.2285 - val_loss: 2412.2939
# Epoch 22/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2962.5728 - val_loss: 2396.0647
# Epoch 23/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2942.8179 - val_loss: 2378.6851
# Epoch 24/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2920.7539 - val_loss: 2360.3040
# Epoch 25/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2897.5464 - val_loss: 2340.6577
# Epoch 26/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2873.2649 - val_loss: 2319.6021
# Epoch 27/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2847.8213 - val_loss: 2297.1062
# Epoch 28/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2819.9614 - val_loss: 2273.4414
# Epoch 29/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2789.0967 - val_loss: 2248.6685
# Epoch 30/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2759.4387 - val_loss: 2222.1443
# Epoch 31/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2725.6499 - val_loss: 2194.3867
# Epoch 32/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2691.1357 - val_loss: 2165.1926
# Epoch 33/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2655.3057 - val_loss: 2134.6597
# Epoch 34/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2617.2893 - val_loss: 2102.9258
# Epoch 35/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2577.3735 - val_loss: 2070.0747
# Epoch 36/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2535.8530 - val_loss: 2035.9023
# Epoch 37/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2493.2349 - val_loss: 2000.3694
# Epoch 38/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2448.0745 - val_loss: 1963.6088
# Epoch 39/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2401.4438 - val_loss: 1925.7502
# Epoch 40/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2354.4116 - val_loss: 1886.9193
# Epoch 41/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2303.6440 - val_loss: 1847.6348
# Epoch 42/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2254.0471 - val_loss: 1807.0494
# Epoch 43/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2201.2942 - val_loss: 1765.8685
# Epoch 44/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2149.5288 - val_loss: 1723.8997
# Epoch 45/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2094.4290 - val_loss: 1681.6644
# Epoch 46/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2040.0424 - val_loss: 1638.8373
# Epoch 47/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1986.0098 - val_loss: 1595.7275
# Epoch 48/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1925.3621 - val_loss: 1553.5598
# Epoch 49/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1870.8004 - val_loss: 1511.0110
# Epoch 50/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1816.7249 - val_loss: 1468.7317
# Epoch 51/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1757.2197 - val_loss: 1427.9733
# Epoch 52/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1701.8489 - val_loss: 1387.7683
# Epoch 53/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1650.4232 - val_loss: 1348.0709
# Epoch 54/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1595.1787 - val_loss: 1310.2335
# Epoch 55/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1541.6863 - val_loss: 1274.2457
# Epoch 56/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1491.9113 - val_loss: 1239.9388
# Epoch 57/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1437.5883 - val_loss: 1207.7894
# Epoch 58/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1389.3964 - val_loss: 1176.4595
# Epoch 59/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1343.0974 - val_loss: 1146.5999
# Epoch 60/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1300.2600 - val_loss: 1118.7843
# Epoch 61/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1255.4955 - val_loss: 1093.8103
# Epoch 62/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1214.5809 - val_loss: 1071.5725
# Epoch 63/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1177.6846 - val_loss: 1051.8071
# Epoch 64/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1140.4075 - val_loss: 1034.5771
# Epoch 65/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1110.9453 - val_loss: 1019.4999
# Epoch 66/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1082.5413 - val_loss: 1007.0251
# Epoch 67/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1051.6056 - val_loss: 997.2299
# Epoch 68/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1030.6472 - val_loss: 989.3262
# Epoch 69/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1009.0355 - val_loss: 983.5453
# Epoch 70/100
# 3/3 [==============================] - 0s 20ms/step - loss: 989.1981 - val_loss: 979.7123
# Epoch 71/100
# 3/3 [==============================] - 0s 19ms/step - loss: 973.9861 - val_loss: 977.5557
# Epoch 72/100
# 3/3 [==============================] - 0s 20ms/step - loss: 962.2438 - val_loss: 976.8011
# Epoch 73/100
# 3/3 [==============================] - 0s 16ms/step - loss: 949.5385 - val_loss: 977.1442
# Epoch 74/100
# 3/3 [==============================] - 0s 15ms/step - loss: 940.3358 - val_loss: 978.2669
# Epoch 75/100
# 3/3 [==============================] - 0s 16ms/step - loss: 931.8580 - val_loss: 979.9225
# Epoch 76/100
# 3/3 [==============================] - 0s 15ms/step - loss: 924.7040 - val_loss: 981.9578
# Epoch 77/100
# 3/3 [==============================] - 0s 16ms/step - loss: 919.3756 - val_loss: 984.3857
# 1/1 [==============================] - 0s 60ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 85ms/step - loss: 3087.4282 - val_loss: 2995.8091
# Epoch 2/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3082.5681 - val_loss: 2991.5610
# Epoch 3/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3078.3418 - val_loss: 2987.3967
# Epoch 4/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3074.3291 - val_loss: 2983.4348
# Epoch 5/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3070.3523 - val_loss: 2979.6772
# Epoch 6/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3066.4907 - val_loss: 2976.1021
# Epoch 7/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3062.8833 - val_loss: 2972.5781
# Epoch 8/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3059.5698 - val_loss: 2969.0718
# Epoch 9/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3055.8469 - val_loss: 2965.5027
# Epoch 10/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3052.2087 - val_loss: 2961.6648
# Epoch 11/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3048.2075 - val_loss: 2957.4209
# Epoch 12/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3043.7805 - val_loss: 2952.7026
# Epoch 13/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3038.8521 - val_loss: 2947.6362
# Epoch 14/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3033.7527 - val_loss: 2942.2073
# Epoch 15/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3028.1626 - val_loss: 2936.4539
# Epoch 16/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3022.2012 - val_loss: 2930.3472
# Epoch 17/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3016.1621 - val_loss: 2923.8228
# Epoch 18/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3009.2878 - val_loss: 2916.9536
# Epoch 19/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3002.2524 - val_loss: 2909.6187
# Epoch 20/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2994.9004 - val_loss: 2901.8318
# Epoch 21/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2986.8494 - val_loss: 2893.6245
# Epoch 22/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2978.1831 - val_loss: 2884.9185
# Epoch 23/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2969.4370 - val_loss: 2875.5481
# Epoch 24/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2959.8936 - val_loss: 2865.5422
# Epoch 25/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2949.7625 - val_loss: 2854.9089
# Epoch 26/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2938.2136 - val_loss: 2843.6887
# Epoch 27/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2927.0813 - val_loss: 2831.4958
# Epoch 28/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2914.6777 - val_loss: 2818.5491
# Epoch 29/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2901.2095 - val_loss: 2804.7971
# Epoch 30/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2886.9573 - val_loss: 2790.1882
# Epoch 31/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2872.2087 - val_loss: 2774.6301
# Epoch 32/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2856.0552 - val_loss: 2758.0767
# Epoch 33/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2839.3140 - val_loss: 2740.4644
# Epoch 34/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2821.3621 - val_loss: 2721.9343
# Epoch 35/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2802.3699 - val_loss: 2702.4575
# Epoch 36/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2782.6335 - val_loss: 2681.8704
# Epoch 37/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2761.6440 - val_loss: 2660.2251
# Epoch 38/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2740.2129 - val_loss: 2637.5034
# Epoch 39/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2715.5327 - val_loss: 2614.2017
# Epoch 40/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2692.8257 - val_loss: 2589.4373
# Epoch 41/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2668.2917 - val_loss: 2563.6785
# Epoch 42/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2641.4548 - val_loss: 2536.9468
# Epoch 43/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2614.7603 - val_loss: 2509.1052
# Epoch 44/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2586.1694 - val_loss: 2480.3687
# Epoch 45/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2557.6558 - val_loss: 2450.4558
# Epoch 46/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2527.0286 - val_loss: 2419.6067
# Epoch 47/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2495.8618 - val_loss: 2387.5962
# Epoch 48/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2463.9597 - val_loss: 2354.4817
# Epoch 49/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2430.3892 - val_loss: 2320.5420
# Epoch 50/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2396.0349 - val_loss: 2285.6196
# Epoch 51/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2361.8521 - val_loss: 2249.4641
# Epoch 52/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2324.5032 - val_loss: 2212.5776
# Epoch 53/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2287.6184 - val_loss: 2174.8335
# Epoch 54/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2249.9673 - val_loss: 2136.0425
# Epoch 55/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2210.8140 - val_loss: 2096.3394
# Epoch 56/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2172.4465 - val_loss: 2055.7734
# Epoch 57/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2132.1255 - val_loss: 2014.7966
# Epoch 58/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2090.8198 - val_loss: 1973.6355
# Epoch 59/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2051.6499 - val_loss: 1932.1375
# Epoch 60/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2009.2744 - val_loss: 1891.0416
# Epoch 61/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1968.9714 - val_loss: 1849.2142
# Epoch 62/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1927.6414 - val_loss: 1807.0013
# Epoch 63/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1886.6195 - val_loss: 1764.7230
# Epoch 64/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1843.2578 - val_loss: 1722.7992
# Epoch 65/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1804.7747 - val_loss: 1679.8826
# Epoch 66/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1763.2883 - val_loss: 1637.6586
# Epoch 67/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1721.2166 - val_loss: 1596.3623
# Epoch 68/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1681.6996 - val_loss: 1555.1859
# Epoch 69/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1641.5286 - val_loss: 1514.5402
# Epoch 70/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1602.2430 - val_loss: 1474.2535
# Epoch 71/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1563.2751 - val_loss: 1434.3972
# Epoch 72/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1525.5232 - val_loss: 1395.0056
# Epoch 73/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1488.7819 - val_loss: 1356.1001
# Epoch 74/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1451.0602 - val_loss: 1318.3011
# Epoch 75/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1412.6552 - val_loss: 1281.8160
# Epoch 76/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1383.8008 - val_loss: 1245.1444
# Epoch 77/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1349.5336 - val_loss: 1210.6785
# Epoch 78/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1316.3445 - val_loss: 1178.0632
# Epoch 79/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1287.1064 - val_loss: 1146.5516
# Epoch 80/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1259.4119 - val_loss: 1116.5234
# Epoch 81/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1232.5510 - val_loss: 1088.3049
# Epoch 82/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1205.1023 - val_loss: 1062.0880
# Epoch 83/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1179.9080 - val_loss: 1036.9199
# Epoch 84/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1159.7686 - val_loss: 1012.0665
# Epoch 85/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1137.8455 - val_loss: 988.9487
# Epoch 86/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1117.2279 - val_loss: 967.4382
# Epoch 87/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1099.5017 - val_loss: 946.7853
# Epoch 88/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1081.1543 - val_loss: 927.6909
# Epoch 89/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1064.4670 - val_loss: 909.7415
# Epoch 90/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1049.4290 - val_loss: 892.9164
# Epoch 91/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1037.8083 - val_loss: 877.2469
# Epoch 92/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1022.8771 - val_loss: 863.8517
# Epoch 93/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1012.4440 - val_loss: 851.1370
# Epoch 94/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1002.8466 - val_loss: 839.2596
# Epoch 95/100
# 3/3 [==============================] - 0s 19ms/step - loss: 996.0850 - val_loss: 828.2520
# Epoch 96/100
# 3/3 [==============================] - 0s 18ms/step - loss: 988.6240 - val_loss: 818.8352
# Epoch 97/100
# 3/3 [==============================] - 0s 18ms/step - loss: 980.4225 - val_loss: 811.0399
# Epoch 98/100
# 3/3 [==============================] - 0s 18ms/step - loss: 973.9752 - val_loss: 804.2020
# Epoch 99/100
# 3/3 [==============================] - 0s 19ms/step - loss: 970.1287 - val_loss: 797.6994
# Epoch 100/100
# 3/3 [==============================] - 0s 18ms/step - loss: 965.1683 - val_loss: 792.0606
# 1/1 [==============================] - 0s 57ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 80ms/step - loss: 3176.0945 - val_loss: 2554.8157
# Epoch 2/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3168.6521 - val_loss: 2547.6694
# Epoch 3/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3161.5825 - val_loss: 2540.7493
# Epoch 4/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3154.3794 - val_loss: 2534.1694
# Epoch 5/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3147.7273 - val_loss: 2527.6714
# Epoch 6/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3140.8750 - val_loss: 2520.5845
# Epoch 7/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3133.7319 - val_loss: 2513.0356
# Epoch 8/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3125.6438 - val_loss: 2505.0989
# Epoch 9/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3117.1973 - val_loss: 2496.6257
# Epoch 10/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3108.2339 - val_loss: 2487.5684
# Epoch 11/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3098.6685 - val_loss: 2477.9480
# Epoch 12/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3087.8972 - val_loss: 2467.8501
# Epoch 13/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3077.9211 - val_loss: 2456.9832
# Epoch 14/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3066.0317 - val_loss: 2445.5298
# Epoch 15/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3053.9941 - val_loss: 2433.3130
# Epoch 16/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3040.3730 - val_loss: 2420.3938
# Epoch 17/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3026.9775 - val_loss: 2406.4480
# Epoch 18/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3011.4194 - val_loss: 2391.6658
# Epoch 19/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2995.9883 - val_loss: 2375.6667
# Epoch 20/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2978.1628 - val_loss: 2358.7234
# Epoch 21/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2959.7612 - val_loss: 2340.6008
# Epoch 22/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2940.7463 - val_loss: 2321.1401
# Epoch 23/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2919.5859 - val_loss: 2300.5347
# Epoch 24/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2896.9556 - val_loss: 2278.8020
# Epoch 25/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2873.8835 - val_loss: 2255.7095
# Epoch 26/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2848.3550 - val_loss: 2231.4302
# Epoch 27/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2822.3928 - val_loss: 2205.6648
# Epoch 28/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2793.9026 - val_loss: 2178.6348
# Epoch 29/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2764.3149 - val_loss: 2150.2048
# Epoch 30/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2732.4290 - val_loss: 2120.4480
# Epoch 31/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2700.1489 - val_loss: 2089.0105
# Epoch 32/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2665.4978 - val_loss: 2056.2251
# Epoch 33/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2629.5464 - val_loss: 2022.0289
# Epoch 34/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2592.4075 - val_loss: 1986.3285
# Epoch 35/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2553.4976 - val_loss: 1949.5696
# Epoch 36/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2512.2251 - val_loss: 1911.9666
# Epoch 37/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2469.7104 - val_loss: 1873.2717
# Epoch 38/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2426.9563 - val_loss: 1833.3207
# Epoch 39/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2382.9077 - val_loss: 1792.3740
# Epoch 40/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2337.1008 - val_loss: 1750.8414
# Epoch 41/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2289.9182 - val_loss: 1708.8718
# Epoch 42/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2242.1072 - val_loss: 1666.1062
# Epoch 43/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2192.3572 - val_loss: 1622.5641
# Epoch 44/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2142.7214 - val_loss: 1578.2908
# Epoch 45/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2091.5437 - val_loss: 1533.5193
# Epoch 46/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2037.6840 - val_loss: 1488.4064
# Epoch 47/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1988.0590 - val_loss: 1442.7158
# Epoch 48/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1933.9072 - val_loss: 1397.7976
# Epoch 49/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1881.6111 - val_loss: 1353.4860
# Epoch 50/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1825.7708 - val_loss: 1310.3425
# Epoch 51/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1773.0094 - val_loss: 1267.5754
# Epoch 52/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1722.1921 - val_loss: 1225.4404
# Epoch 53/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1670.3457 - val_loss: 1184.5381
# Epoch 54/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1616.6458 - val_loss: 1145.1274
# Epoch 55/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1565.6892 - val_loss: 1106.8296
# Epoch 56/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1517.6759 - val_loss: 1069.8363
# Epoch 57/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1470.7742 - val_loss: 1034.9907
# Epoch 58/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1419.3530 - val_loss: 1003.2571
# Epoch 59/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1378.6061 - val_loss: 972.8828
# Epoch 60/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1333.9246 - val_loss: 945.3381
# Epoch 61/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1295.1207 - val_loss: 920.1833
# Epoch 62/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1255.1472 - val_loss: 897.8358
# Epoch 63/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1220.4202 - val_loss: 877.9523
# Epoch 64/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1188.1008 - val_loss: 860.7812
# Epoch 65/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1154.9929 - val_loss: 846.3674
# Epoch 66/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1126.9568 - val_loss: 834.2123
# Epoch 67/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1099.4355 - val_loss: 824.4873
# Epoch 68/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1079.2307 - val_loss: 816.7382
# Epoch 69/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1053.2396 - val_loss: 811.3465
# Epoch 70/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1035.2849 - val_loss: 807.7471
# Epoch 71/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1018.6685 - val_loss: 806.0238
# Epoch 72/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1004.1774 - val_loss: 806.0167
# Epoch 73/100
# 3/3 [==============================] - 0s 15ms/step - loss: 992.4011 - val_loss: 807.4882
# Epoch 74/100
# 3/3 [==============================] - 0s 14ms/step - loss: 978.8745 - val_loss: 809.9111
# Epoch 75/100
# 3/3 [==============================] - 0s 15ms/step - loss: 972.4225 - val_loss: 813.3031
# Epoch 76/100
# 3/3 [==============================] - 0s 15ms/step - loss: 963.6854 - val_loss: 817.0511
# Epoch 77/100
# 3/3 [==============================] - 0s 16ms/step - loss: 957.7676 - val_loss: 821.1377
# 1/1 [==============================] - 0s 57ms/step

# %%
# Calculate the average scores over all folds
avg_mse = np.mean(mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_mae = np.mean(mae_scores)
avg_r2 = np.mean(r2_scores)

# Print the results
print(f"Average Mean Squared Error: {avg_mse:.2f}%")
print(f"Average Root Mean Squared Error: {avg_rmse:.2f}%")
print(f"Average Mean Absolute Error: {avg_mae:.2f}%")
print(f"Average R-squared: {avg_r2:.2f}%")
# Out:
# Average Mean Squared Error: 974.93%
# Average Root Mean Squared Error: 32.11%
# Average Mean Absolute Error: 27.22%
# Average R-squared: -15.55%

# %%
# Find the most optimal production volume to minimize manufacturing cost
min_production_volume = supply_data['Production volumes'].min()
max_production_volume = 1000
step_size = 100

cheapest_cost = float('inf')
best_production_volume = None

for production_volume in range(min_production_volume, max_production_volume + 1, step_size):
    normalized_production_volume = scaler.transform(np.array([[production_volume]]))
    predicted_cost = model.predict(normalized_production_volume)

    if predicted_cost[0][0] < cheapest_cost:
        cheapest_cost = predicted_cost[0][0]
        best_production_volume = production_volume

print('Most optimal production volume to minimize manufacturing cost:', best_production_volume)
print('The cheapest manufacturing cost:', cheapest_cost)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Most optimal production volume to minimize manufacturing cost: 104
# The cheapest manufacturing cost: 22.439837
